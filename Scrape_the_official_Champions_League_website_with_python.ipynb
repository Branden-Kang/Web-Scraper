# %% [markdown]
# [Reference](https://towardsdev.com/scrape-the-official-champions-league-website-with-python-7ad81d8f044c)

# %%
import pandas as pd
import warnings
import requests
from bs4 import BeautifulSoup



warnings.filterwarnings('ignore')

urls = ['https://www.uefa.com/uefachampionsleague/match/2035649--dinamo-zagreb-vs-chelsea/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035651--celtic-vs-real-madrid/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035653--dortmund-vs-copenhagen/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035650--salzburg-vs-milan/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035652--leipzig-vs-shakhtar-donetsk/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035654--sevilla-vs-man-city/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035656--benfica-vs-m-haifa/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035655--paris-vs-juventus/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035641--ajax-vs-rangers/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035647--frankfurt-vs-sporting-cp/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035642--napoli-vs-liverpool/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035644--club-brugge-vs-leverkusen/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035643--atletico-vs-porto/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035646--inter-vs-bayern/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035645--barcelona-vs-plzen/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035648--tottenham-vs-marseille/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035661--plzen-vs-inter/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035657--liverpool-vs-ajax/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035660--leverkusen-vs-atletico/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035664--marseille-vs-frankfurt/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035663--sporting-cp-vs-tottenham/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035659--porto-vs-club-brugge/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035662--bayern-vs-barcelona/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035665--milan-vs-dinamo-zagreb/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035658--rangers-vs-napoli/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035668--real-madrid-vs-leipzig/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035670--copenhagen-vs-sevilla/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035672--m-haifa-vs-paris/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035667--shakhtar-donetsk-vs-celtic/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035666--chelsea-vs-salzburg/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035669--man-city-vs-dortmund/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035671--juventus-vs-benfica/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035677--bayern-vs-plzen/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035673--liverpool-vs-rangers/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035675--porto-vs-leverkusen/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035678--inter-vs-barcelona/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035679--marseille-vs-sporting-cp/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035674--ajax-vs-napoli/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035676--club-brugge-vs-atletico/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035680--frankfurt-vs-tottenham/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035681--salzburg-vs-dinamo-zagreb/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035682--chelsea-vs-milan/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035685--man-city-vs-copenhagen/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035687--juventus-vs-m-haifa/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035683--leipzig-vs-celtic/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035684--real-madrid-vs-shakhtar-donetsk/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035686--sevilla-vs-dortmund/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035688--benfica-vs-paris/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035701--copenhagen-vs-man-city/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035697--dinamo-zagreb-vs-salzburg/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035699--shakhtar-donetsk-vs-real-madrid/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035702--dortmund-vs-sevilla/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035703--m-haifa-vs-juventus/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035698--milan-vs-chelsea/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035700--celtic-vs-leipzig/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035704--paris-vs-benfica/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035689--napoli-vs-ajax/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035690--rangers-vs-liverpool/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035693--barcelona-vs-inter/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035695--tottenham-vs-frankfurt/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035691--atletico-vs-club-brugge/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035692--leverkusen-vs-porto/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035696--sporting-cp-vs-marseille/statistics/',
'https://www.uefa.com/uefachampionsleague/match/2035694--plzen-vs-bayern/statistics/']

ucl_df = []

ucl_df = pd.DataFrame(ucl_df,columns=['FixtureName', 'Team', 'ball_possession', 'attempts', 'attacks',
       'corners', 'passes_accuracy', 'passes_completed', 'passes_attempted',
       'recovered_ball', 'offsides', 'saves', 'distance_covered',
       'yellow_cards', 'red_cards', 'goals',
       'goals_scored_inside_penalty_area', 'goals_scored_outside_penalty_area',
       'attempts', 'attempts_on_target', 'attempts_off_target', 'blocked',
       'attempts_on_woodwork', 'attempts_on_bar', 'attempts_on_post',
       'attempts_on_target_outside_penalty_area',
       'attempts_off_target_outside_penalty_area', 'assists', 'penalty_scored',
       'penalty_miss', 'penalty_awarded', 'attacks', 'big_chance', 'corners',
       'offsides', 'dribbling', 'run_solo_into_attacking_third',
       'run_solo_into_key_play_area', 'run_solo_into_penalty_area',
       'ball_possession', 'passes_accuracy', 'passes_completed',
       'passes_attempted', 'passes_short_completed', 'passes_medium_completed',
       'passes_long_completed', 'passes_completed_backward',
       'passes_completed_to_left', 'passes_completed_to_right', 'free_kick',
       'delivery_into_attacking_third', 'delivery_into_key_play_area',
       'delivery_into_penalty_area', 'cross_accuracy', 'cross_completed',
       'cross_attempted', 'instance_of_possession', 'recovered_ball',
       'blocked', 'penalty_conceded', 'tackles', 'tackles_won', 'tackles_lost',
       'clearance_completed', 'clearance_attempted', 'goals_conceded',
       'own_goal_conceded', 'clean_sheet', 'saves',
       'saves_on_direct_free_kick', 'saves_on_indirect_free_kick',
       'saves_on_penalty', 'claims', 'claims_high', 'claims_low', 'punches',
       'yellow_cards', 'red_cards', 'fouls_committed',
       'fouls_committed_in_defensive_third', 'fouls_committed_in_own_half'])


for url in urls:
# Scraping the data
   soup = BeautifulSoup(requests.get(url).content)
   game_stats = soup.find_all("pk-list-stat-item", class_ = 'js-live-stat')
   MatchName_raw = soup.find_all("h1", class_ = 'hideTitle')

   #Retrieve the match name
   MatchNames = [m.text for m in MatchName_raw]
   #turn into df.
   Fixture = pd.DataFrame(MatchNames,columns=['Data'])
   #cleaning

   Fixture['HomeTeam'] = [i.split('vs', 1)[0] for i in Fixture['Data']]
   Fixture['FixtureName'] = [i.split('Stats: UEFA Champions League Group stage 2022/23', 1)[0] for i in Fixture['Data']]

   Fixture['AwayTeam'] = [i.split('vs', 1)[1] for i in Fixture['FixtureName']]

   match_name = Fixture['FixtureName'].loc[Fixture['FixtureName'].index.repeat(2)].reset_index(drop=True)


   teams = Fixture[['HomeTeam','AwayTeam']]

   teams = teams.T.stack().reset_index()
   teams = pd.DataFrame(teams)
   TeamNames = pd.DataFrame(teams[0])
   TeamNames.columns = ['Team']

# retrieve the data columns
   columns = [m.get('data-stat-type') for m in game_stats]

#split by home/away

   HomeTeamData = [m.get('data') for m in game_stats]
   AwayTeamData = [m.get('second-data') for m in game_stats]

# create dataframes and concat the stats

   HomeTeamData1 = pd.DataFrame(HomeTeamData)
   HomeTeamData1 = HomeTeamData1.T

   AwayTeamData1 = pd.DataFrame(AwayTeamData)
   AwayTeamData1 = AwayTeamData1.T

   HomeTeamData1.columns = columns
   AwayTeamData1.columns = columns

   ingame_stats = pd.concat([HomeTeamData1,AwayTeamData1]).reset_index(drop=True)
#final concat
   ucl_data = pd.concat([match_name,TeamNames,ingame_stats],axis=1)
   ucl_df = ucl_df.append(ucl_data)
   continue

ucl_df = ucl_df.loc[:,~ucl_df.columns.duplicated()]
ucl_df.Team = ucl_df.Team.str.lstrip()

ucl_df = ucl_df[['FixtureName', 'Team', 'ball_possession', 'attempts', 'attacks',
       'corners', 'passes_accuracy', 'passes_completed', 'passes_attempted',
       'recovered_ball', 'offsides', 'distance_covered',
       'yellow_cards', 'red_cards', 'goals',
       'goals_scored_inside_penalty_area', 'goals_scored_outside_penalty_area', 'attempts_on_target', 'attempts_off_target', 'blocked',
       'attempts_on_target_outside_penalty_area',
       'attempts_off_target_outside_penalty_area', 'assists', 'penalty_scored',
       'penalty_miss', 'penalty_awarded', 'big_chance', 'passes_short_completed', 'passes_medium_completed',
       'passes_long_completed', 'passes_completed_backward',
       'passes_completed_to_left', 'passes_completed_to_right', 'tackles', 'tackles_won', 'tackles_lost',
       'fouls_committed_in_defensive_third', 'fouls_committed_in_own_half']]

ucl_df
# Out:
#                   FixtureName            Team ball_possession attempts  \
# 0   Dinamo Zagreb vs Chelsea   Dinamo Zagreb               38        6
# 1   Dinamo Zagreb vs Chelsea         Chelsea               62       15
# 0      Celtic vs Real Madrid          Celtic               36       10
# 1      Celtic vs Real Madrid     Real Madrid               64       12
# 0     Dortmund vs Copenhagen        Dortmund               60       15
# ..                        ...             ...             ...      ...
# 1        Leverkusen vs Porto           Porto               36        5
# 0   Sporting CP vs Marseille     Sporting CP               34        4
# 1   Sporting CP vs Marseille       Marseille               66       17
# 0            Plzeň vs Bayern           Plzeň               35       15
# 1            Plzeň vs Bayern          Bayern               65       15
#
#    attacks corners passes_accuracy passes_completed passes_attempted  \
# ...
