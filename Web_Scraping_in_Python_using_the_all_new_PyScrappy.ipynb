# %% [markdown]
# [Reference](https://medium.com/analytics-vidhya/web-scraping-in-python-using-the-all-new-pyscrappy-5c136ed6906b)

# %%
pip install PyScrappy
# Out:
# ...
#      |████████████████████████████████| 904 kB 7.3 MB/s
# ...

# %%
import PyScrappy
PyScrappy.flipkart_scrapper('notebook', 1) # product_name, n_pages
# Out:
#                                                  Name  ... Rating
# 0       Classmate Pulse A4 Notebook Unruled 300 Pages  ...    4.5
# 1       Classmate Pulse A4 Notebook Unruled 180 Pages  ...    4.4
# 2   Classmate Pulse Regular Notebook Single Line 3...  ...    4.5
# 3   Classmate Pulse A4 Notebook Single Line 300 Pages  ...    4.2
# 4   Classmate Longbook Regular Notebook Single Lin...  ...    4.5
# 5   Classmate Notebook A4 Notebook Single Line 172...  ...    4.5
# 6         Camlin Premio A4 Notebook Unruled 200 Pages  ...    4.6
# 7   Classmate Notebook 240mm x 180mm Book-size Not...  ...    4.3
# 8   Classmate Longbook A4 Notebook Single Line 240...  ...    4.6
# 9   Classmate Pulse 6 Subject (267 X 203 mm) Spira...  ...    4.5
# 10  NAVNEET Youva Spiral Bound 21x29.7 cm A4 Noteb...  ...    4.4
# 11  Classmate Notebook Book-size Notebook Single L...  ...    4.1
# 12  Classmate Pulse Book-size Notebook Unruled 180...  ...    4.2
# ...

# %%
PyScrappy.flipkart_scrapper('notebook', 6)
# Out:
#                                                   Name  ... Rating
# 0        Classmate Pulse A4 Notebook Unruled 300 Pages  ...    4.5
# 1        Classmate Pulse A4 Notebook Unruled 180 Pages  ...    4.4
# 2    Classmate Pulse A4 Notebook Single Line 300 Pages  ...    4.2
# 3    Classmate Origami 24 x 18 cm Book-size Noteboo...  ...    4.1
# 4    NAVNEET Youva Case Bound My Notes 14.8x21 cm A...  ...    4.3
# ..                                                 ...  ...    ...
# 235  Classmate Long Notebook 297mm x 162mm Book-siz...  ...    4.2
# 236  LUXOR Exercise Notebook-Spiral A4 Notebook Rul...  ...    4.2
# 237  doodle Beeping Love Notebook B6 Notebook Ruled...  ...    4.5
# 238  LUXOR Exercise Notebook-Green B5 Notebook Rule...  ...    4.3
# 239  Classmate Notebook Mini Notebook Single Line S...  ...    3.5
#
# [240 rows x 5 columns]

# %%
example = PyScrappy.WikipediaScrapper()
example

# %%
example.text_scrapper('Python (programming language)')
# Out:
# ' History Python is an interpreted high-level general-purpose programming language. Python\'s design philosophy emphasizes code readability with its notable use of significant indentation. Its language constructs as well as its object-oriented approach aim to help programmers write clear, logical code for small and large-scale projects. Design philosophy and features Python is dynamically-typed and garbage-collected. It supports multiple programming paradigms, including structured (particularly, procedural), object-oriented and functional programming. Python is often described as a "batteries included" language due to its comprehensive standard library. Syntax and semantics Guido van Rossum began working on Python in the late 1980s, as a successor to the ABC programming language, and first released it in 1991 as Python 0.9.0. Python\xa02.0 was released in 2000 and introduced new features, such as list comprehensions and a garbage collection system using reference counting. Python\xa0
# ...

# %%
PyScrappy.image_scrapper('dog', 10, 'png', 'dogs') # data, n_images, img_format, folder_name)
# Out:
# Folder Exist with that name!
# Enter a new Folder name:
# dogs_
# Starting to Download...
# 'Successfully Downloaded 0 images'
