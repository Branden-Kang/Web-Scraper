# %% [markdown]
# [Reference](https://medium.com/@chidiebere.vincent/practical-web-scraping-for-data-analysts-b02ec8b8adb7)

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import csv

# %%
# Function to format the data and print result
def print_phone_data(phone_data_format, csv_writer):
    for record in phone_data_format:
        csv_writer.writerow(record)

num_pages_to_scrape = 50

# %%
base_url = 'https://www.jumia.com.ng/mobile-phones/?shipped_from=country_local&page='
url_separator = '#catalog-listing'
headers = {'User-Agent': 'Chrome/58.0.3029.110'}

# full_url = 'https://www.jumia.com.ng/mobile-phones/?shipped_from=country_local&page=50#catalog-listing'

phone_data_format_all_pages = []

# %%
for page_num in range(1, num_pages_to_scrape + 1):
    url = base_url + str(page_num) + url_separator
    response = requests.get(url)
    soupcontent = BeautifulSoup(response.content, 'html.parser')

    phones = soupcontent.find_all('div', {'class': 'info'})
    phone_data_format =[]
    for i in phones:
        name_element = i.find('h3', {'class': 'name'})
        price_element = i.find('div', {'class': 'prc'})
        official_store_element = i.find('div', {'class': 'bdg _mall _xs'})
        discount_element = i.find('div', {'class': 'bdg _dsct _sm'})
        rating_element = i.find('div', {'class':'rev'})
        old_element = i.find('div', {'class':'old'})

# Check if elements are found before accessing their text
        if name_element:
            name = name_element.get_text().replace('\xa0', ' ')
        else:
            name = 'N/A'

        if price_element:
            price = price_element.get_text().replace('\xa0', ' ')
        else:
            price = 'N/A'

        if official_store_element:
            official_store = official_store_element.get_text().replace('\xa0', ' ')
        else:
            official_store = 'N/A'

        if discount_element:
            discount = discount_element.get_text().replace('\xa0', ' ')
        else:
            discount = 'N/A'

        if rating_element:
            rating = rating_element.get_text().replace('\xa0', ' ')
        else:
            rating = 'N/A'

        if old_element:
            old_price = old_element.get_text().replace('\xa0', ' ')
        else:
            old_price = 'N/A'

 # Format the data
        format_name = ' '.join(name.strip().replace('\n', '').split())
        format_price = ' '.join(price.strip().replace('₦', '').split())
        format_official_store = ' '.join(official_store.strip().replace('\n', '').split())
        format_discount = ' '.join(discount.strip().replace('%', '').split())
        format_rating = ' '.join(rating.strip().replace('\n', '').split())
        format_old = ' '.join(old_price.strip().replace('₦', '').split())

    # Print formatted phone details
        record = [format_name, format_price, format_official_store, format_discount, format_rating, format_old]
        phone_data_format.append(record)

    # Extend the phone_data_format_all_pages list with the data from the current page
    phone_data_format_all_pages.extend(phone_data_format)

csv_file_path = 'Jumia1.csv'
with open(csv_file_path, 'w', newline = '', encoding = 'utf-8') as csvfile:
    csv_writer = csv.writer(csvfile)

    # Write Header
    csv_writer.writerow(['Phone Name', 'Price', 'Official Store', 'Discount', 'Rating', 'old price'])

    # Write data
    print_phone_data(phone_data_format_all_pages, csv_writer)

# %%
phone_data_format_all_pages
# Out:
# [['XIAOMI Redmi 12C 6.71" 3GB RAM/64GB ROM Android 12 - Graphite Grey',
#   '74,000',
#   'Official Store',
#   '25',
#   '4.2 out of 5(263)',
#   '98,500'],
#  ['Tecno Spark 10c 6.6" 4GB RAM/128GB ROM Android 13 Black',
#   '97,800',
#   'Official Store',
#   '31',
#   '4.3 out of 5(213)',
#   '140,980'],
#  ['Infinix Smart 7 Plus 6.6"HD+ 3GB RAM/64GB ROM Android 12 - Black',
#   '97,355',
#   'Official Store',
#   '7',
#   '4.2 out of 5(26)',
#   '105,000'],
#  ['Tecno Camon 20 6.67" 8GB/256GB Android 13 -GlacierGlow',
#   '179,200',
#   'Official Store',
#   '38',
#   '4.6 out of 5(103)',
#   '288,461'],
#  ['FreeYond F9,2GB+64GB,6.52" Smartphone,4G,5000mAh,Black',
#   '61,946',
#   'N/A',
#   '32',
#   '4.3 out of 5(119)',
#   '91,000'],
#  ['Samsung Galaxy A03 Core 6.5" 2GB RAM/ 32GB ROM Android 11- Onyx Black',
#   '69,000',
#   'Official Store',
#   '27',
#   '4.2 out of 5(212)',
#   '94,740'],
#  ['Infinix Smart 7 Plus 6.6"HD+, 3GB RAM + 64GB ROM, 6000mAh, 4G, Green',
#   '97,355',
#   'Official Store',
#   '7',
#   '4.5 out of 5(8)',
#   '105,000'],
#  ['XIAOMI Redmi A2+ 6.52 2GB RAM/32GB ROM Android 12 - Black',
#   '61,800',
#   'Official Store',
#   '13',
#   '4.2 out of 5(248)',
#   '71,000'],
#  ['Tecno Spark 10c 6.6" 4GB RAM/128GB ROM Android 13 Blue',
#   '97,800',
#   'Official Store',
#   '35',
#   '4.2 out of 5(187)',
#   '150,174'],
#  ['Tecno Camon 20 6.67" 8GB RAM/256GB Android 13 - Blue - Free Gift',
#   '179,200',
#   'Official Store',
#   '38',
#   '4.4 out of 5(100)',
#   '288,461'],
#  ['Samsung Galaxy A24 6.5" 6GB RAM/128GB ROM Android 13 - Black',
#   '267,830',
#   'Official Store',
#   '8',
#   '4.6 out of 5(71)',
#   '290,000'],
#  ['FreeYond M5,4GB+128GB,4G 6.52" Smartphone 5000mAh,Grey',
#   '93,906',
#   'N/A',
#   '47',
#   '1.3 out of 5(3)',
#   '176,275'],
#  ['Infinix Note 30 6.67" 8GB RAM/256GB ROM Android 13 - Black+ Gift',
#   '196,500',
#   'Official Store',
#   '30',
#   '4.1 out of 5(7)',
#   '282,283'],
#  ['Infinix HOT 30i (X669) 6.56"-128GB/4GB UPTO 8GBRAM- Android™12- Gold',
#   '126,000',
#   'Official Store',
#   '16',
#   '4.2 out of 5(21)',
#   '150,000'],
#  ['Infinix Note30 6.66" 128GB/8GB RAM Android 13 -Black',
#   '176,700',
#   'Official Store',
#   '34',
#   '4.7 out of 5(21)',
#   '269,538'],
#  ['UMIDIGI A11 6.53" 3GB RAM/64GB ROM Android 11 - Mist Blue',
#   '59,595',
#   'Official Store',
#   '42',
#   '4.2 out of 5(207)',
#   '102,660'],
#  ['Samsung Galaxy A14 6.6" 4GB RAM/128GB ROM Android 13 - Black',
#   '155,890',
#   'Official Store',
#   '20',
#   '4.3 out of 5(339)',
#   '195,000'],
#  ['Infinix Smart 7 HD 6.6" 2GB RAM/64GB ROM Android 12 - Green',
#   '69,000',
#   'Official Store',
#   '38',
#   '4.2 out of 5(50)',
#   '111,000'],
#  ['UMIDIGI G1 6.52" 2GB RAM/32GB ROM Android 12 - Galaxy Blue',
#   '65,599',
#   'Official Store',
#   '33',
#   '4.2 out of 5(25)',
#   '98,420'],
#  ['Infinix HOT 30i 6.56" 4GB RAM/128GB ROM Android 12 - Black',
#   '108,000',
#   'Official Store',
#   '40',
#   '4.3 out of 5(211)',
#   '180,300'],
#  ["XIAOMI Redmi A2+ 6.52'' 2GB RAM/32GB ROM Android 12 - Blue",
#   '61,800',
#   'Official Store',
#   '13',
#   '4.2 out of 5(16)',
#   '71,000'],
#  ['Tecno POP 7 6.6" 2GB RAM/ 64GB ROM Android 12 - Blue',
#   '69,500',
#   'Official Store',
#   '41',
#   '4.3 out of 5(197)',
#   '118,026'],
#  ['Tecno POP 7 6.6" 2GB RAM/ 64GB ROM Android 12 - Black',
#   '69,500',
#   'Official Store',
#   '41',
#   '4.3 out of 5(133)',
#   '118,026'],
#  ['Nokia 110 1.77" Dual SIM Torch -Green',
#   '10,900',
#   'Official Store',
#   '27',
#   '4.4 out of 5(92)',
#   '15,000'],
#  ['XIAOMI Poco C40 6.71” 4GB RAM/64GB ROM Android 11 - Black',
#   '88,895',
#   'Official Store',
#   '27',
#   '4.5 out of 5(54)',
#   '121,910'],
#  ['XIAOMI Redmi A2+ 6.71" 3GB RAM/64GB ROM Android 12 - Black',
#   '76,800',
#   'Official Store',
#   '22',
#   '4.4 out of 5(98)',
#   '99,000'],
#  ['FreeYond M5A,8GB+256GB,4G 6.6" Smartphone 5000mAh,Black',
#   '101,095',
#   'N/A',
#   '35',
#   '4 out of 5(41)',
#   '155,378'],
#  ['Samsung Galaxy A14 6.6" 4GB RAM/64GB ROM Android 13 - Black',
#   '139,900',
#   'Official Store',
#   '17',
#   '4.4 out of 5(179)',
#   '169,000'],
#  ['Tecno Spark 10c 6.6" 4GB RAM/128GB ROM Android 13 MagicskinBlue',
#   '97,800',
#   'Official Store',
#   '35',
#   '4.3 out of 5(22)',
#   '150,174'],
#  ['DCQ Q4 1.77 Camera 1.3 2600mAh Phone - Black',
#   '8,400',
#   'N/A',
#   '16',
#   '4 out of 5(558)',
#   '10,000'],
#  ['Samsung Galaxy A04s 6.5" 4GB RAM/128GB ROM Android 12 - Black',
#   '130,000',
#   'Official Store',
#   '18',
#   '4.5 out of 5(101)',
#   '159,500'],
#  ['XIAOMI Redmi A2+ 6.52" 2GB RAM/32GB ROM Android 12 - Black',
#   '61,800',
#   'Official Store',
#   '13',
#   '4.3 out of 5(18)',
#   '71,000'],
#  ['Tecno Pop 7 Pro 6.6" 3GB RAM/64GB ROM Android 12 Black',
#   '81,700',
#   'Official Store',
#   '30',
#   '4.2 out of 5(77)',
#   '116,159'],
#  ['Infinix Smart 7 Plus 6.6" 3GB RAM/64GB ROM Android 12- Green',
#   '83,900',
#   'Official Store',
#   '35',
#   '4.3 out of 5(53)',
#   '129,026'],
#  ['XIAOMI Redmi A2+ 6.71" 2GB RAM/32GB ROM Android 12 - Black',
#   '66,800',
#   'Official Store',
#   '33',
#   '4.4 out of 5(72)',
#   '99,000'],
#  ['itel A18 5.0" 1GB RAM/32GB ROM Android 11 - Morion Grey',
#   '46,990',
#   'Official Store',
#   '6',
#   '4 out of 5(137)',
#   '50,000'],
#  ['XIAOMI Redmi A2+ 6.52" 3GB RAM/64GB ROM Android 12 - Light Blue',
#   '76,800',
#   'Official Store',
#   '22',
#   '3.8 out of 5(11)',
#   '99,000'],
#  ['AGM Note N1 6.52" 8GB Base RAM/8GB Extended RAM/128GB ROM Android 13 - Grey',
#   '101,972',
#   'Official Store',
#   '32',
#   '4.3 out of 5(69)',
#   '150,000'],
#  ['UMIDIGI A13S 6.7" 4GB RAM/64GB ROM Android 11 - Galaxy Blue',
#   '65,399',
#   'Official Store',
#   '34',
#   '4.1 out of 5(203)',
#   '99,100'],
#  ['Refurbished OPPO A3S 6.2 "HD+ 4GB+64GB , 4230mAH Blue',
#   '53,990',
#   'N/A',
#   '23',
#   '4 out of 5(196)',
#   '69,990'],
#  ['Infinix Hot 30i 6.6" 4GB RAM/128GB ROM Android 12 - White',
#   '103,000',
#   'Official Store',
#   '45',
#   '4.2 out of 5(72)',
#   '186,300'],
#  ['XIAOMI Redmi A2+ 6.52" 2GB RAM/32GB ROM Android 12 - Light Blue',
#   '66,800',
#   'Official Store',
#   '33',
#   '4.4 out of 5(50)',
#   '99,000'],
#  ['Infinix Smart 7 Plus 6.6" 3GB RAM/64GB ROM Android 12 - Blue',
#   '83,900',
#   'Official Store',
#   '41',
#   '3.7 out of 5(23)',
#   '142,207'],
#  ['Nokia 110 Africa Edition Dual SIM Wireless FM, Torch, Camera Phone',
#   '13,990',
#   'N/A',
#   '22',
#   '4.4 out of 5(90)',
#   '18,000'],
#  ['FreeYond F9,3GB+128GB,4G 6.52" Smartphone 5000mAh,Black',
#   '70,475',
#   'N/A',
#   '35',
#   '4 out of 5(61)',
#   '109,000'],
#  ['Samsung Galaxy A04e 6.5" 3GB RAM/64GB ROM Android 12 - Black',
#   '92,000',
#   'Official Store',
#   '12',
#   '4.5 out of 5(51)',
#   '105,000'],
#  ['Infinix Smart 7 HD 2GB RAM 64GB ROM 5000mAh - Green',
#   '71,000',
#   'Official Store',
#   '5',
#   '4.7 out of 5(14)',
#   '75,000'],
#  ['Infinix Hot 30i 6.6" 4GB RAM/128GB ROM Android 12 - Blue',
#   '103,000',
#   'Official Store',
#   '45',
#   '4.3 out of 5(128)',
#   '186,300'],
#  ['Nokia 110 Africa Edition Dual SIM Wireless FM, Torch, Camera Phone',
#   '13,990',
#   'Official Store',
#   '22',
#   '4.1 out of 5(97)',
#   '18,000'],
#  ['FreeYond F9,3GB+128GB,6.52",4G, Smartphone 5000mAh,Blue',
#   '71,578',
#   'N/A',
#   '34',
#   '4.2 out of 5(36)',
#   '109,000'],
#  ['XIAOMI Redmi 12 6.79" 8GB RAM/256GB ROM Android 13 - Midnight Black',
#   '172,500',
#   'Official Store',
#   '13',
#   '4.2 out of 5(68)',
#   '199,000'],
#  ['Tecno Spark 10 5G (KI8) 6.6", 256GB/ 8GB RAM, 5000mAh, 5G - Black',
#   '122,900',
#   'N/A',
#   '25',
#   '5 out of 5(4)',
#   '162,900'],
#  ['DCQ Q1 2.4 5D Louder Speaker 2000mAh Phone - Black',
#   '8,400',
#   'N/A',
#   '30',
#   '4.1 out of 5(121)',
#   '12,000'],
#  ['Samsung Galaxy A04s 6.5" 4GB RAM/64GB ROM Android 12- Black',
#   '138,580',
#   'Official Store',
#   '2',
#   '4.5 out of 5(118)',
#   '140,770'],
#  ['Tecno Spark 10 6.6" 8GB RAM/128GB ROM Android 12 Black',
#   '123,400',
#   'Official Store',
#   '36',
#   '4.4 out of 5(76)',
#   '193,202'],
#  ['XIAOMI Redmi Note 12 6.67" 8GB RAM/128GB ROM Android 12 - Onyx Gray',
#   '181,300',
#   'Official Store',
#   '7',
#   '4.4 out of 5(76)',
#   '195,000'],
#  ['itel S23 6.6" 4GB RAM/128GB ROM Android 12 - Black',
#   '125,000',
#   'Official Store',
#   'N/A',
#   '4.3 out of 5(76)',
#   'N/A'],
#  ['Tecno POP 7 6.6" 2GB RAM/64GB ROM Android 12 - Purple',
#   '69,500',
#   'Official Store',
#   '50',
#   '4.2 out of 5(39)',
#   '139,330'],
#  ['itel S23 6.6" 90Hz HD+, 128GB ROM + Up To 8GB RAM, 5000mAh Type-C, 50MP Clear Camera, 4G, Fingerprint & Face ID - White',
#   '96,450',
#   'N/A',
#   '4',
#   '3.9 out of 5(29)',
#   '100,000'],
#  ['IPhone 5s 4.0 Inch 8MP IOS Smartphones Refurbished 95% New',
#   '44,000',
#   'N/A',
#   '45',
#   '3.9 out of 5(8)',
#   '80,000'],
#  ['XIAOMI Redmi Note 12 6.67" 4GB RAM/128GB ROM Android 13 - Onyx Gray',
#   '168,000',
#   'Official Store',
#   '7',
#   '3.9 out of 5(31)',
#   '180,000'],
#  ['Infinix Hot 30 Play 6.82" 8GB RAM/128GB ROM Android 13 - White',
#   '146,300',
#   'Official Store',
#   '44',
#   '3.5 out of 5(20)',
#   '260,000'],
#  ['itel P40 Plus 6.6" 4GB RAM/128GB ROM Android 13 - Black',
#   '102,000',
#   'Official Store',
#   '32',
#   '4.5 out of 5(57)',
#   '150,000'],
#  ['UMIDIGI BISON X10 Pro 6.53" 4GB RAM/128GB ROM Android 11 -Gray',
#   '82,899',
#   'Official Store',
#   '22',
#   '4.5 out of 5(15)',
#   '106,300'],
#  ['Samsung Galaxy A04e 6.5" 3GB RAM/32GB ROM Android 12 - Black',
#   '92,900',
#   'Official Store',
#   '14',
#   '4.2 out of 5(74)',
#   '108,000'],
#  ['XIAOMI Redmi 12 6.79" 4GB RAM/128GB ROM Android 13 - Midnight Black',
#   '146,170',
#   'Official Store',
#   '6',
#   '4.3 out of 5(24)',
#   '155,000'],
#  ['XIAOMI Redmi 12 6.79" 4GB RAM/128GB ROM Android 13 - Midnight Black',
#   '147,500',
#   'Official Store',
#   '26',
#   '4.2 out of 5(40)',
#   '199,000'],
#  ['Samsung Galaxy A03 Core 6.5" 2GB RAM/32GB ROM Android 11 - Bronze',
#   '69,000',
#   'Official Store',
#   '27',
#   '4.5 out of 5(114)',
#   '94,740'],
#  ['Tecno Spark 10C (KI5k) 6.6", 128GB + Up To 8GB RAM, 16MP, 5000mAh',
#   '119,990',
#   'N/A',
#   '29',
#   '4.2 out of 5(59)',
#   '170,000'],
#  ['Infinix Zero Ultra 6.67", 256GB + 8GB RAM, 200MP, 180W Charge - Noir',
#   '260,000',
#   'N/A',
#   '36',
#   '4 out of 5(2)',
#   '405,500'],
#  ['FreeYond F9,(4+4)GB+64GB,6.52" Smartphone,4G,5000mAh,Grey',
#   '69,466',
#   'N/A',
#   '36',
#   '3.8 out of 5(28)',
#   '109,000'],
#  ['itel 2160 Wireless FM, Bright Torchlight, Call Recorder, Dual SIM Mobile - Blue',
#   '10,950',
#   'Official Store',
#   '27',
#   '4.4 out of 5(141)',
#   '15,000'],
#  ['XIAOMI Redmi A2+ 6.52” 2GB RAM/32GB ROM Android 12 - Light Green',
#   '66,800',
#   'Official Store',
#   '33',
#   '3.9 out of 5(59)',
#   '99,000'],
#  ['Tecno Pop 7 Pro 6.6" 3GB RAM/64GB ROM Android 12 Purple',
#   '81,700',
#   'Official Store',
#   '31',
#   '4.4 out of 5(60)',
#   '119,216'],
#  ['itel A04 6.3" HD+ Screen, 2GB RAM + 32GB ROM, 4000mAh, 5MP Camera, 3G, Fingerprint & Face Unlock - Cyan +Free Case',
#   '56,750',
#   'N/A',
#   '29',
#   '4.2 out of 5(29)',
#   '80,000'],
#  ['Infinix Hot 12 6.82" 4GB RAM/128GB ROM Android 12 - Black',
#   '93,000',
#   'Official Store',
#   '15',
#   '4.8 out of 5(4)',
#   '110,000'],
#  ['Zealot S67 Big Battery 60W Wireless Bluetooth Zealot Bass Speaker',
#   '56,300',
#   'N/A',
#   '34',
#   '4.5 out of 5(68)',
#   '85,000'],
#  ['FreeYond F9 6.52" 2GB RAM/64GB ROM Android 12 - Blue',
#   '60,557',
#   'N/A',
#   '33',
#   '3.7 out of 5(34)',
#   '91,000'],
#  ['Infinix Hot 30i 6.6\'" HD+, 4+4GB RAM /128GB ROM Android 12 - Black',
#   '132,356',
#   'Official Store',
#   '5',
#   '4.6 out of 5(15)',
#   '139,000'],
#  ['Oppo A31 6GB RAM+128G ROM Refurbished Dual SIM6.5 Inch Screen HD Camera 12MP Face Unlock+Fingerprint Smartphone',
#   '84,499',
#   'N/A',
#   '16',
#   '4.3 out of 5(23)',
#   '100,999'],
#  ['UMIDIGI A11 6.53" 4GB RAM/128GB ROM Android 11 - Mist Blue',
#   '78,583',
#   'Official Store',
#   '24',
#   '4.1 out of 5(487)',
#   '102,850'],
#  ['UMIDIGI A13S 6.7" HD+ 4GB RAM/64GB ROM Android 11 - Sunglow Gold',
#   '65,399',
#   'Official Store',
#   '34',
#   '4.1 out of 5(96)',
#   '99,100'],
#  ['UMIDIGI A11S 6.53" 4GB RAM/64GB ROM Android 11 -Frost Grey',
#   '61,475',
#   'Official Store',
#   '40',
#   '3.8 out of 5(228)',
#   '102,600'],
#  ['UMIDIGI A11S 6.53" 4GB RAM/64GB ROM Android 11 -Mist Blue',
#   '59,690',
#   'Official Store',
#   '42',
#   '4 out of 5(76)',
#   '102,600'],
#  ['Infinix Smart 7 HD 2GB RAM 64GB ROM 5000mAh - White',
#   '71,000',
#   'Official Store',
#   '5',
#   '5 out of 5(2)',
#   '75,000'],
#  ['Samsung GALAXY S23 ULTRA 5G (12GB+256GB) MOBILE - BEIGE',
#   '1,236,945',
#   'N/A',
#   '25',
#   'N/A',
#   '1,650,000'],
#  ['Infinix Note 30 6.66" 128GB/8GB RAM Android 13 -Gold- Free Speaker',
#   '176,700',
#   'Official Store',
#   '15',
#   '4.4 out of 5(46)',
#   '207,717'],
#  ['Tecno Spark 10 (KI5q) 6.6", 128GB + Up To 16GB RAM- 50MP, 5000mAh',
#   '128,500',
#   'N/A',
#   '8',
#   '4.4 out of 5(29)',
#   '140,000'],
#  ['Tecno Spark 10 Pro 6.8" 8GB RAM/128GB ROM Android 13 - Black',
#   '134,200',
#   'Official Store',
#   '37',
#   '4.5 out of 5(64)',
#   '213,043'],
#  ['Tecno Camon 20 PRO (8GB RAM+256GB ROM) 5000MAH- Blue',
#   '223,000',
#   'Official Store',
#   '11',
#   'N/A',
#   '250,000'],
#  ['XIAOMI Redmi 12 6.79"4GB RAM/128GB ROM Android 13 - Polar Silver',
#   '147,500',
#   'Official Store',
#   '22',
#   '3.8 out of 5(5)',
#   '189,000'],
#  ['itel P40 Plus 6.6", 128GB ROM + Up To 8GB RAM, 7000mAh 18W, 13MP',
#   '106,990',
#   'N/A',
#   '24',
#   '4.3 out of 5(13)',
#   '140,000'],
#  ['Tecno Spark 10C (KI5k) 6.6" HD+ 90Hz, 128GB ROM + Up To 8GB RAM, 16MP + 8MP Selfie, 5000mAh Type-C, 4G - Blue',
#   '115,950',
#   'N/A',
#   '32',
#   '4.4 out of 5(50)',
#   '170,000'],
#  ['Infinix Smart 7 HD 6.6" 2GB RAM/64GB ROM Android 12 - Black',
#   '72,500',
#   'Official Store',
#   '27',
#   '3.8 out of 5(16)',
#   '99,000'],
#  ['Infinix HOT 30i- (X669) -128/4GB \'6.56"-13MP+8MP AI DUAL FLASH Camera-5000mAh-Android™ 12- Black',
#   '126,000',
#   'N/A',
#   '16',
#   '4.5 out of 5(22)',
#   '150,000'],
#  ['XIAOMI Redmi 12 6.79" 8GB RAM/256GB ROM Android 13 - Sky Blue',
#   '172,500',
#   'Official Store',
#   '13',
#   '4.3 out of 5(33)',
#   '199,000'],
#  ['itel A18 5.0" 1GB RAM/32GB ROM Android 11 - Blue',
#   '47,250',
#   'Official Store',
#   '6',
#   '3.8 out of 5(33)',
#   '50,000'],
#  ['QUBO Big1 Plus 6.26" 2GB RAM/32GB ROM Android 10 - Blue',
#   '40,990',
#   'Official Store',
#   '37',
#   '3.8 out of 5(298)',
#   '65,135'],
#  ['Blackview Oscal C20 6.088" 1GB RAM/32GB ROM Android 11 - Black',
#   '48,621',
#   'Official Store',
#   '46',
#   '3.5 out of 5(323)',
#   '90,283'],
#  ['AGM Note N1 6.52" 8GB Base RAM/8GB Extended RAM/128GB ROM Android 13- Blue',
#   '97,872',
#   'Official Store',
#   '35',
#   '4.2 out of 5(34)',
#   '150,000'],
#  ["Samsung Galaxy Note 10 (8gb+ 256GB) 6.3'',12MP 2x Zoom, 16MP Ultra Wide Rear+10MP Selfie Camera With Dual Pixel,3500mAh - Black",
#   '245,000',
#   'N/A',
#   '13',
#   '4.4 out of 5(14)',
#   '280,000'],
#  ['Tecno Camon 20 (8GB RAM+256GB ROM) 5000MAH Black',
#   '183,240',
#   'Official Store',
#   '27',
#   'N/A',
#   '250,000'],
#  ['XIAOMI Redmi Note 12 6.67" 6GB RAM/128GB ROM Android 12 - Blue',
#   '174,650',
#   'Official Store',
#   '6',
#   '4.3 out of 5(3)',
#   '185,000'],
#  ['Tecno POP 7 (BF6) 6.6" HD+ 2GB RAM/64GB ROM Android 12 - Black',
#   '74,490',
#   'Official Store',
#   '17',
#   '4.5 out of 5(23)',
#   '90,000'],
#  ['Tecno POP 7 6.6" 2GB RAM/ 64GB ROM Android 12 - Black',
#   '67,500',
#   'N/A',
#   '32',
#   '3.6 out of 5(8)',
#   '99,999'],
#  ['QUBO X668 6.53" HD+ 4GB RAM/64GB ROM Android 11 - Blue',
#   '59,990',
#   'Official Store',
#   '45',
#   '3.9 out of 5(296)',
#   '109,990'],
#  ['UMIDIGI BISON X10 6.53" 4GB RAM/64GB ROM Android 11 - Black',
#   '70,781',
#   'Official Store',
#   '29',
#   '4 out of 5(25)',
#   '99,600'],
#  ['XIAOMI Redmi Note 12 Smartphone 6.67" GOLED Display 120Hz',
#   '168,475',
#   'N/A',
#   '6',
#   '5 out of 5(2)',
#   '179,862'],
#  ['itel 5626 2.8" Screen, 2500mAh Battery, Triple SIM, Loudspeaker',
#   '19,990',
#   'Official Store',
#   '33',
#   '4.4 out of 5(12)',
#   '30,000'],
#  ['Tecno Camon 20 (CK6) 6.67" 8GB RAM/256GB ROM Android 13 -Black',
#   '193,950',
#   'Official Store',
#   '35',
#   '4.9 out of 5(8)',
#   '300,000'],
#  ['XIAOMI Redmi A1+ 6.52" 2GB RAM/32GB ROM Android 12 - Black',
#   '63,825',
#   'Official Store',
#   '11',
#   '3.8 out of 5(13)',
#   '71,640'],
#  ['Infinix Smart 7 HD 6.6" 2GB RAM/64GB ROM Android 12 - White',
#   '72,500',
#   'Official Store',
#   '27',
#   '3.7 out of 5(10)',
#   '99,000'],
#  ['Infinix Note 30 Pro 6.67" 8GB RAM/256GB ROM Android 13 - Black+ Gift',
#   '256,900',
#   'Official Store',
#   '28',
#   '3.2 out of 5(5)',
#   '357,771'],
#  ['Tecno Spark 10 Pro 6.8 8/128 GB Android 13 LTE-Lunar Eclipse',
#   '132,500',
#   'Official Store',
#   '12',
#   '5 out of 5(1)',
#   '150,000'],
#  ['itel 5626 2.8" Screen 2500mAh Battery',
#   '19,990',
#   'Official Store',
#   '33',
#   '4.6 out of 5(54)',
#   '30,000'],
#  ['Infinix HOT 30i (X669)- 128/4GB- \'6.56"-13MP+8MP-5000mAh',
#   '126,000',
#   'N/A',
#   '3',
#   '4.8 out of 5(5)',
#   '130,000'],
#  ['Samsung Galaxy A04 6.5" 4GBRAM /64GB ROM Android 12 - Black',
#   '125,250',
#   'Official Store',
#   '3',
#   '4.4 out of 5(32)',
#   '129,000'],
#  ['itel P40 6.6" 4GB RAM/64GB ROM Android 12 - Black',
#   '68,590',
#   'Official Store',
#   '19',
#   '4.3 out of 5(15)',
#   '85,000'],
#  ['Blackview A80 Plus 6.49" 4GB RAM/64GB ROM Android 10 - Black',
#   '70,805',
#   'Official Store',
#   '46',
#   '4.1 out of 5(41)',
#   '131,765'],
#  ['Infinix HOT 30i- (X669)- 128/4GB- \'6.56"-13MP+8MP-5000mAh',
#   '126,000',
#   'N/A',
#   '16',
#   '5 out of 5(1)',
#   '150,000'],
#  ['Infinix Note 10 Pro 6.95" FHD+ 8GB RAM/128GB ROM Android 11 - Nordic Secret',
#   '185,000',
#   'Official Store',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['XIAOMI Redmi 9A 6.53" 4GB RAM/64GB ROM Android 10 - Gray',
#   '88,550',
#   'Official Store',
#   '23',
#   '4.8 out of 5(12)',
#   '114,281'],
#  ['Tecno Camon 20 6.67" 8GB RAM/256GB ROM Android 13 - Blue',
#   '179,200',
#   'Official Store',
#   '38',
#   '4.2 out of 5(33)',
#   '288,461'],
#  ['UMIDIGI Power 5S 6.53" 4GB RAM/32GB ROM Android 11 - Jade Green',
#   '58,561',
#   'Official Store',
#   '43',
#   '3.9 out of 5(106)',
#   '101,850'],
#  ['Infinix Hot 30 Play 6.82" 8GB RAM/128GB ROM Android 13 - Black',
#   '158,950',
#   'Official Store',
#   '14',
#   '4.6 out of 5(28)',
#   '185,000'],
#  ['Tecno Spark 10 5G 6.6" 8GB RAM/256GB ROM Android 13 - Black',
#   '140,000',
#   'Official Store',
#   '3',
#   '5 out of 5(1)',
#   '145,000'],
#  ['Samsung Galaxy A04s 6.5" 4GB RAM/64GB ROM Android 12 - Copper',
#   '110,580',
#   'Official Store',
#   '21',
#   '4.7 out of 5(20)',
#   '140,770'],
#  ['Tecno Spark 10C (KI5k) 6.6" HD+ 90Hz, 128GB ROM + Up To 8GB RAM, 16MP + 8MP Selfie, 5000mAh Type-C, 4G - Black',
#   '131,990',
#   'N/A',
#   '22',
#   '4.3 out of 5(50)',
#   '170,000'],
#  ['Tecno Spark 9 Pro - 6.6"fhd+ - 128GB ROM- 4GB RAM - Dual Sim-50mp - 5000mAh - Fingerprint - Kyanite Blue',
#   '128,030',
#   'N/A',
#   '4',
#   '2 out of 5(1)',
#   '133,030'],
#  ['Tecno Camon 20 6.67" 8GB RAM/256GB ROM Android 13 - Black',
#   '202,000',
#   'N/A',
#   '28',
#   '4 out of 5(1)',
#   '280,500'],
#  ['Nokia G60 5G 6.58" 6GB/128GB ROM Android 12 - Pure Black',
#   '234,990',
#   'Official Store',
#   '4',
#   '4.7 out of 5(7)',
#   '245,000'],
#  ['Samsung Galaxy A14 6.6" 4GB RAM/64GB ROM Android 13 - Light Green',
#   '144,950',
#   'Official Store',
#   '19',
#   '4.4 out of 5(64)',
#   '179,000'],
#  ['itel S23 6.6" 128GB + 4GB RAM, 5000mAh 50MP BLACK',
#   '102,000',
#   'N/A',
#   '32',
#   '4.7 out of 5(6)',
#   '150,000'],
#  ['Tecno POP 7 (BF6) 6.6" HD+ 2GB RAM/64GB ROM Android 12 - Blue',
#   '74,650',
#   'Official Store',
#   '17',
#   '4.3 out of 5(129)',
#   '90,000'],
#  ['UMIDIGI G1 6.52" 2GB RAM/32GB ROM Android 12- Sunglow Gold',
#   '61,663',
#   'Official Store',
#   '37',
#   '4.3 out of 5(56)',
#   '98,420'],
#  ['UMIDIGI A11S 6.53" 4GB RAM/32GB ROM Android 11 - Mist Blue',
#   '58,655',
#   'Official Store',
#   '42',
#   '4 out of 5(96)',
#   '101,840'],
#  ["XIAOMI Redmi A2+ 6.52'' 3GB RAM/64GB ROM Android 12 - Black",
#   '70,800',
#   'Official Store',
#   '13',
#   '4.7 out of 5(3)',
#   '81,000'],
#  ['UMIDIGI Power 5 6.53" 3GB RAM/64GB ROM Android 11 - Sapphire Blue',
#   '60,629',
#   'Official Store',
#   '41',
#   '4.1 out of 5(35)',
#   '102,660'],
#  ["Blackview Oscal C20Pro 6'' 32GB RAM/2GB ROM 4G Android 11- Blue",
#   '56,991',
#   'Official Store',
#   '44',
#   '4.1 out of 5(77)',
#   '101,639'],
#  ['XIAOMI Redmi 12C 6.71" 3GB RAM/64GB ROM Android 12 - Graphite Gray',
#   '86,300',
#   'Official Store',
#   '9',
#   '4.2 out of 5(55)',
#   '95,000'],
#  ['UMIDIGI BISON X10S 6.53" 4GB RAM/64GB ROM Android 11 Global Version -Gray',
#   '67,773',
#   'Official Store',
#   '32',
#   '4.3 out of 5(4)',
#   '99,600'],
#  ['Blackview A55 Pro 6.528" 4GB RAM/64GB ROM Android 11 - Black',
#   '73,668',
#   'Official Store',
#   '44',
#   '3.8 out of 5(37)',
#   '131,330'],
#  ['UMIDIGI A11 6.53" 3GB/64GB ROM Android 11 - Frost Grey',
#   '59,595',
#   'Official Store',
#   '42',
#   '4.1 out of 5(265)',
#   '102,600'],
#  ['Blackview A70Pro 6.517" 4GB RAM/32GB ROM Android11- Blue',
#   '65,990',
#   'Official Store',
#   '53',
#   '4.1 out of 5(16)',
#   '139,200'],
#  ['AGM HUXIAO Big Louder Speaker, FM Radio, SOS, Dual SIM Torch',
#   '20,875',
#   'N/A',
#   '26',
#   '4.8 out of 5(8)',
#   '28,164'],
#  ['UMIDIGI A11S 6.53" 4GB RAM/32GB ROM Android 11 - Frost Grey',
#   '61,475',
#   'Official Store',
#   '40',
#   '4 out of 5(135)',
#   '101,840'],
#  ['Tecno Spark 9 Pro - 6.6" FHD 128GB ROM- 4GB RAM - Dual Sim-50mp - 5000mAh - Fingerprint - Quantum Black',
#   '128,030',
#   'N/A',
#   '4',
#   '3.7 out of 5(3)',
#   '133,030'],
#  ['UMIDIGI G1 6.52" HD+ 2GB RAM/32GB ROM Android 12 - Starry Black',
#   '61,663',
#   'Official Store',
#   '37',
#   '4.4 out of 5(61)',
#   '98,420'],
#  ['UMIDIGI C1 6.52" HD 2GB RAM/32GB ROM Android 12 -Matte Silver',
#   '58,561',
#   'Official Store',
#   '40',
#   '4 out of 5(24)',
#   '98,420'],
#  ['UMIDIGI Power 5 6.53" 3GB/64GB ROM Android 11 -Jade Green',
#   '57,527',
#   'Official Store',
#   '44',
#   '4.1 out of 5(39)',
#   '102,600'],
#  ['UMIDIGI BISON X10G 6.53" 4GB RAM/64GB ROM Android 11 - Black',
#   '70,781',
#   'Official Store',
#   '29',
#   '4 out of 5(27)',
#   '99,600'],
#  ['UMIDIGI C1 6.52" HD 2GB RAM/32GB ROM Android 12 -Hawaii Blue',
#   '59,598',
#   'Official Store',
#   '39',
#   '4 out of 5(22)',
#   '98,420'],
#  ['UMIDIGI BISON X10S 6.53" 4GB RAM/32GB ROM Android 11 -Gray',
#   '66,739',
#   'Official Store',
#   '31',
#   '4.1 out of 5(19)',
#   '96,840'],
#  ['UMIDIGI Power 5S 6.53" 4GB RAM/64GB ROM Android 11 - Sapphire Blue',
#   '64,499',
#   'Official Store',
#   '37',
#   '4.3 out of 5(31)',
#   '102,600'],
#  ["Blackview Oscal C20 Pro 6.08'' 2GB RAM/32GB ROM Android 11- Black",
#   '58,897',
#   'Official Store',
#   '45',
#   '4 out of 5(20)',
#   '107,059'],
#  ["Blackview A556.528'' 3GB RAM/16GB ROM Android 11- Black",
#   '61,990',
#   'Official Store',
#   '46',
#   '4.1 out of 5(8)',
#   '115,752'],
#  ['Tecno Phantom V Fold 5G (AD10) 512GB + 12GB RAM, 50MP Quint Camera',
#   '1,007,400',
#   'N/A',
#   '33',
#   'N/A',
#   '1,500,000'],
#  ["Blackview Oscal C60 6.52'' 4GB RAM/32GB ROM Android11- Meteorite Black",
#   '68,900',
#   'Official Store',
#   '43',
#   '4.3 out of 5(3)',
#   '119,986'],
#  ['UMIDIGI BISON X10G 6.53" 4GB RAM/32GB ROM Android 11 Global Version -Black',
#   '70,518',
#   'Official Store',
#   '27',
#   '3.9 out of 5(8)',
#   '96,840'],
#  ['UMIDIGI Power 5S 6.53" 4GB RAM/32GB ROM Android 11 - Sapphire Blue',
#   '58,561',
#   'Official Store',
#   '43',
#   '4.1 out of 5(88)',
#   '101,850'],
#  ['Tecno Camon 20 Premier 5G (CK9n) 512GB + 8GB RAM, 5000mAh - Welkin',
#   '399,100',
#   'N/A',
#   '11',
#   'N/A',
#   '449,100'],
#  ["Blackview A55 Pro 6.528'' 4GB RAM/64GB ROM Android 11- Blue",
#   '73,668',
#   'Official Store',
#   '44',
#   '3.8 out of 5(15)',
#   '131,330'],
#  ["Blackview A55Pro 6.528'' 4GB RAM/64GB ROM Android 11 -White",
#   '75,990',
#   'Official Store',
#   '45',
#   '4.3 out of 5(3)',
#   '137,564'],
#  ['UMIDIGI C1 6.52" HD+ 2GB RAM/32GB ROM Android 12 -Starry Black',
#   '65,599',
#   'Official Store',
#   '33',
#   '4.1 out of 5(20)',
#   '98,420'],
#  ["Blackview A80S 6.21'' 4GB RAM/64GB ROM Android 10 - Black",
#   '73,535',
#   'Official Store',
#   '45',
#   '3.8 out of 5(30)',
#   '133,441'],
#  ['AGM M6 Louder Speaker Dual SIM Wireless FM Bright Torchlight',
#   '41,250',
#   'Official Store',
#   '35',
#   '3 out of 5(2)',
#   '63,390'],
#  ['Blackview A7Pro 6.517" 4GB RAM/32GB ROM Android 11 - Black',
#   '79,156',
#   'Official Store',
#   '36',
#   '4.4 out of 5(58)',
#   '124,537'],
#  ['UMIDIGI Power 5S 6.53" 4GB RAM/32GB ROM Android 11 - Carbon Grey',
#   '57,527',
#   'Official Store',
#   '44',
#   '3.8 out of 5(62)',
#   '101,850'],
#  ['QUBO Big1 Plus 6.26" 2GB RAM/32GB ROM Android 10 - Red',
#   '40,990',
#   'Official Store',
#   '37',
#   '3.7 out of 5(226)',
#   '65,135'],
#  ['Oppo A31 6GB RAM+128G ROM Refurbished Dual SIM6.5 Inch Screen HD Camera 12MP Face Unlock+Fingerprint Smartphone',
#   '84,499',
#   'N/A',
#   '16',
#   '4.5 out of 5(4)',
#   '100,999'],
#  ['AGM M2, 2.8" Dual SIM, Torch, FM Radio, Camera Feature Phone',
#   '41,250',
#   'Official Store',
#   '21',
#   '1 out of 5(1)',
#   '51,900'],
#  ['Nokia G21 - 6.5" (4GB RAM, 64GB ROM) Android 11 (50/2/2)MP + 8MP Selfie - Dual Sim - 4G LTE - 5050mAh - Nordic Blue',
#   '109,990',
#   'Official Store',
#   '19',
#   '4 out of 5(3)',
#   '135,500'],
#  ['itel S23 6.6", 128GB ROM + Up To 8GB RAM, 50MP Camera, 5000mAh',
#   '95,990',
#   'N/A',
#   '4',
#   '4.3 out of 5(45)',
#   '100,000'],
#  ['Firman SUPER 15000MAH POWER BANK WITH INBUILT CABLES',
#   '10,916',
#   'N/A',
#   '73',
#   '2 out of 5(1)',
#   '40,100'],
#  ['Tecno Pop 7 Pro (BF7) 6.6" 3GB RAM/64GB ROM Android 12 - Black',
#   '89,950',
#   'Official Store',
#   '25',
#   '5 out of 5(3)',
#   '120,000'],
#  ['Jikokoa Xtra Foreign Charcoal Stove Grill Burner(big Size)',
#   '29,000',
#   'N/A',
#   'N/A',
#   '5 out of 5(1)',
#   'N/A'],
#  ['Nokia G21 - 6.5" (4GB RAM, 128GB ROM) Android 11 (50/2/2)MP + 8MP Selfie - Dual Sim - 4G LTE - 5050mAh - DUSK',
#   '128,900',
#   'N/A',
#   '8',
#   '4 out of 5(5)',
#   '140,000'],
#  ['XIAOMI Poco C40 6.71" 4GB RAM/64GB ROM Android 11 - Poco Yellow',
#   '89,124',
#   'Official Store',
#   '46',
#   '4.4 out of 5(41)',
#   '165,000'],
#  ['XIAOMI Redmi Note 12 Onyx Gray 6GB RAM 128GB ROM',
#   '189,900',
#   'N/A',
#   '13',
#   '4 out of 5(14)',
#   '219,000'],
#  ['Infinix HOT 30i- (X669) - 128/4GB \'6.6"-13MP Rear AF Dual Camera With Dual Flash Light + 8MP Selfie -5000mAh - Android 12 - Diamond White',
#   '145,000',
#   'N/A',
#   '12',
#   'N/A',
#   '165,000'],
#  ['Nokia C10, 6.5Inch (2GB RAM, 32GB ROM) Android 11, (5MP ) Dual SIM - GREY',
#   '59,990',
#   'N/A',
#   '13',
#   '4.3 out of 5(3)',
#   '69,000'],
#  ['Apple IPhone 14 Pro Max 6.7" 256GB Nano Sim - Deep Purple',
#   '1,600,000',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['XIAOMI Redmi Note 12 Onyx Gray 8GB RAM 128GB ROM',
#   '184,500',
#   'N/A',
#   '20',
#   '4.5 out of 5(23)',
#   '230,000'],
#  ['Samsung Galaxy M33 Dual Sim -6GB RAM - 128GB - 5G -Green',
#   '225,000',
#   'N/A',
#   '15',
#   '4.3 out of 5(4)',
#   '265,000'],
#  ['Apple IPhone 12 Pro Max - 256GB, 6GB RAM, 6.7-Inch,(12MP+12MP+12MP) - Pacific Blue',
#   '820,000',
#   'N/A',
#   'N/A',
#   '5 out of 5(3)',
#   'N/A'],
#  ["Google Pixel 7 5G 6.3'' 8GB 128GB ROM Android 13",
#   '458,850',
#   'N/A',
#   '8',
#   '5 out of 5(1)',
#   '500,000'],
#  ['Apple IPhone 14 Pro Max 6.7" (6GB RAM + 128GB ROM) - Deep Purple',
#   '1,380,000',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['Apple IPhone 13 Pro 6.1 Inch Super Retina XDR Display With ProMotion, (6GB RAM + 256GB ROM), IOS 15, 5G, FaceTime - Graphite',
#   '1,000,000',
#   'N/A',
#   'N/A',
#   '5 out of 5(3)',
#   'N/A'],
#  ['Apple IPhone 13 Pro Max 6.7" Super Retina XDR Display With ProMotion, (6GB RAM + 128GB ROM) IOS 15, 5G, FaceTime - Sierra Blue',
#   '1,030,000',
#   'N/A',
#   'N/A',
#   '5 out of 5(2)',
#   'N/A'],
#  ['Jikokoa Foreign Charcoal Cook Stove Burner Extra (big)',
#   '28,975',
#   'N/A',
#   '3',
#   'N/A',
#   '29,900'],
#  ['Nokia C10, 6.5Inch (2GB RAM, 32GB ROM) Android 11, (5MP ) Dual SIM - Light Purple',
#   '59,990',
#   'N/A',
#   '13',
#   'N/A',
#   '69,000'],
#  ['Kuhl 14Pro Max 6.82FHD,4GB+64GB, 5mp+13mp, 5000 MA Battery Black',
#   '66,000',
#   'N/A',
#   '18',
#   '3.4 out of 5(51)',
#   '80,000'],
#  ['Kuhl 14Pro Max 6.82FHD,4GB+64GB, 5mp+13mp, 5000 MA Battery Gold',
#   '66,000',
#   'N/A',
#   '18',
#   '3.4 out of 5(24)',
#   '80,000'],
#  ['itel P40 6.6" 4GB RAM/64GB ROM Android 12 - Black',
#   '59,999',
#   'Official Store',
#   '12',
#   '4.9 out of 5(17)',
#   '68,500'],
#  ['Titanic T-130 1.77 Screen, Dual SIM Card+memory Card Blue',
#   '5,990',
#   'N/A',
#   '20',
#   '3.7 out of 5(36)',
#   '7,446'],
#  ['IPhone X 3GB RAM+64GB(Renewed) -Black',
#   '213,879',
#   'N/A',
#   '37',
#   '4.1 out of 5(62)',
#   '340,452'],
#  ['DCQ Q6 Dual Card, FM, Flashlight, 800MAH – Black',
#   '6,900',
#   'N/A',
#   '31',
#   '3.9 out of 5(34)',
#   '10,000'],
#  ['IPhone X 3GB RAM+64GB (Renewed) -White',
#   '213,879',
#   'N/A',
#   '37',
#   '4 out of 5(59)',
#   '340,452'],
#  ['Cubot Note 8 5.5" 2GB RAM/16GB ROM Android 11 - Black',
#   '40,000',
#   'Official Store',
#   '36',
#   '3.6 out of 5(27)',
#   '62,944'],
#  ['itel 2163 Wireless FM Torchlight Dual SIM - Black',
#   '8,990',
#   'Official Store',
#   '10',
#   '4.3 out of 5(110)',
#   '10,000'],
#  ['Tecno POP 5 Go 5.71" 16GB ROM/1GB RAM Android 10 - Black',
#   '54,500',
#   'Official Store',
#   '8',
#   '3.9 out of 5(261)',
#   '59,000'],
#  ['Infinix Note 30 Pro Gift Box With Davido\'s Signature 6.67" 8GB RAM/256GB ROM Android 13 - Gold',
#   '256,900',
#   'Official Store',
#   '24',
#   '4.7 out of 5(18)',
#   '335,867'],
#  ['itel 2163 1.8" Wireless FM Torchlight Dual SIM',
#   '8,990',
#   'Official Store',
#   '10',
#   '3.8 out of 5(37)',
#   '10,000'],
#  ['P47 Wireless Bluetooth Headphone',
#   '4,500',
#   'N/A',
#   '55',
#   '3.7 out of 5(12)',
#   '10,000'],
#  ['itel P40 Plus 6.6" 4GB RAM/128GB ROM Android 13 - Cyan',
#   '98,000',
#   'Official Store',
#   '1',
#   '4.3 out of 5(96)',
#   '99,000'],
#  ['itel 2160 Wireless FM,Torchlight, Call Recorder, Dual SIM Phone-BlUE',
#   '8,500',
#   'Official Store',
#   '19',
#   '3.3 out of 5(4)',
#   '10,500'],
#  ['Uniwa E1801 - Dual Sim -2.4" -Camera - Torch-Fm Radio- 800mAh-Black',
#   '7,886',
#   'N/A',
#   '1',
#   '4 out of 5(4)',
#   '7,980'],
#  ['Refurbished Huawei Y9 2020 6.5-inch Fhd+, 8gb+128gb,Blue',
#   '75,950',
#   'N/A',
#   'N/A',
#   '4.1 out of 5(15)',
#   'N/A'],
#  ['Infinix Smart 7 HD 6.6" 2GB RAM/64GB ROM Android 12 - White',
#   '69,000',
#   'Official Store',
#   '38',
#   '3.9 out of 5(38)',
#   '111,000'],
#  ['Samsung Galaxy S10 Plus (S10+) 6.4-Inch AMOLED (8GB, 128GB ROM) (12MP + 12MP + 16MP)+(10MP+8MP) Single SIM 4G Smartphone - Black',
#   '265,000',
#   'N/A',
#   '12',
#   '4.6 out of 5(30)',
#   '300,000'],
#  ['Tecno Spark 10 5G 6.6" 8GB RAM/256GB ROM Android 13 - Black',
#   '142,900',
#   'Official Store',
#   '49',
#   '4.5 out of 5(4)',
#   '280,980'],
#  ['XIAOMI Redmi Note 12S 6.43" 8GB RAM/256GB ROM Android 13 - Black',
#   '219,800',
#   'Official Store',
#   '13',
#   '4.5 out of 5(11)',
#   '254,000'],
#  ['P47 5.0 Wireless Bluetooth Stereo Foldable Headphone',
#   '4,450',
#   'N/A',
#   '56',
#   '3.5 out of 5(6)',
#   '10,000'],
#  ['Nokia 110 1.77" Dual SIM, Torch, FM Radio, Camera Phone - Green',
#   '13,899',
#   'Official Store',
#   '7',
#   '4.5 out of 5(44)',
#   '15,000'],
#  ["Samsung Galaxy S9 5.8'' Inch QHD ( 4GB + 64GB ROM ) 12MP+8MP _ Midnight Black, Single Sim",
#   '145,000',
#   'N/A',
#   '19',
#   '4.3 out of 5(20)',
#   '180,000'],
#  ['itel A70 6.6"HD 4GB RAM 128GB ROM Android 12 - Blue',
#   '78,900',
#   'Official Store',
#   '17',
#   '5 out of 5(1)',
#   '95,000'],
#  ['Oraimo OPB-204D 20000MAH Powerbank Type-C & MicroUSB - BLACK',
#   '15,830',
#   'N/A',
#   '47',
#   '4.1 out of 5(38)',
#   '30,000'],
#  ['itel S23 Plus 6.78", 256GB ROM + Up To 16GB RAM, 5000mAh, 50MP',
#   '187,950',
#   'N/A',
#   '6',
#   '4 out of 5(2)',
#   '200,000'],
#  ['Kuhl S23 Ultra 6.82FHD,4GB+64GB, 5mp+13mp, 5000 MA Battery Black',
#   '66,000',
#   'N/A',
#   '49',
#   '3.2 out of 5(11)',
#   '129,990'],
#  ['Tecno Spark 10C (KI5k) 6.6"- 128GB/4GB RAM, 16MP,+8MP- Android12 5000mAh',
#   '126,500',
#   'N/A',
#   '29',
#   '5 out of 5(2)',
#   '179,000'],
#  ['itel It2160 Wireless Fm, Torchlight, Dual SIM - Dark Blue',
#   '10,900',
#   'N/A',
#   '27',
#   '4.4 out of 5(124)',
#   '15,000'],
#  ['Tecno Spark 10C (KI5k)(4+4GB RAM+128GB ROM) Blue',
#   '135,000',
#   'N/A',
#   'N/A',
#   '4.6 out of 5(9)',
#   'N/A'],
#  ['Tecno Spark 10C (KI5k) 6.6"- 128GB/4GB RAM, 16MP,+8MP- Android12 5000mAh',
#   '126,500',
#   'N/A',
#   '20',
#   '4.8 out of 5(5)',
#   '159,000'],
#  ['XIAOMI Redmi 12C, 6.53-inch ,3GB RAM, 64GB ROM MINT GREEN-5000MAH',
#   '87,000',
#   'N/A',
#   '12',
#   'N/A',
#   '99,000'],
#  ['itel 6360 2.8" Screen, Smart Touch, 2000mAh Dual SIM Feature Phone',
#   '24,750',
#   'N/A',
#   '18',
#   '3.5 out of 5(4)',
#   '30,000'],
#  ['Blueidea Rugged Cordless Rechargeable Hair & Beard Clipper',
#   '6,900',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['Kuhl S23 Ultra 6.82FHD,4GB+64GB, 5mp+13mp, 5000 MA Battery Green',
#   '66,000',
#   'N/A',
#   '49',
#   '1 out of 5(2)',
#   '129,990'],
#  ["Samsung Galaxy Note 9 SingleSim 128gb/6gb 6.4'' Black",
#   '199,000',
#   'N/A',
#   '3',
#   '4.3 out of 5(8)',
#   '205,000'],
#  ['Samsung Galaxy S20 128GB ROM - 8GB RAM Single SIM 5G Black',
#   '257,000',
#   'N/A',
#   '1',
#   '4.3 out of 5(7)',
#   '260,000'],
#  ['XIAOMI Redmi 12 6.79"4GB RAM/128GB ROM Android 13 - Sky Blue',
#   '147,500',
#   'Official Store',
#   '26',
#   '4.6 out of 5(5)',
#   '199,000'],
#  ['Miracle Quality Anti-Fatigue Compression Socks',
#   '2,700',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['itel It2163N,1.77 Screen,Opera Mini, BrightTorch,1000mAh , Black',
#   '9,599',
#   'N/A',
#   '19',
#   '3.8 out of 5(13)',
#   '11,800'],
#  ['itel It 5606 Wireless FM - City Blue',
#   '12,990',
#   'Official Store',
#   '13',
#   '4.2 out of 5(191)',
#   '15,000'],
#  ['Samsung Galaxy S9 Plus Single SIM, 6.2-Inch QHD (6GBRAM, 64GB ROM) 4G LTE Android 9.0 Smartphone Black',
#   '170,000',
#   'N/A',
#   '13',
#   '4.7 out of 5(9)',
#   '195,000'],
#  ['Samsung Galaxy S20 5G 8+128GB G9810 Single Sim - Gray',
#   '260,000',
#   'N/A',
#   '13',
#   'N/A',
#   '300,000'],
#  ['Nokia C1 2nd Edition, (1GB RAM, 16GB ROM) Dual SIM - Purple',
#   '46,900',
#   'N/A',
#   '1',
#   '3.9 out of 5(12)',
#   '47,500'],
#  ['XIAOMI Redmi 12C, 6.53-inch ,3GB RAM, 32GB ROM MINT GREEN-5000MAH',
#   '87,500',
#   'N/A',
#   '3',
#   'N/A',
#   '90,000'],
#  ['XIAOMI Redmi Note 12 6.67" 8GB RAM/128GB ROM Android 13 - Grey',
#   '182,800',
#   'Official Store',
#   '8',
#   '4.6 out of 5(21)',
#   '199,595'],
#  ['Zealot S67 Bluetooth Speaker 60W Output Power Bluetooths',
#   '51,499',
#   'N/A',
#   'N/A',
#   '4.3 out of 5(15)',
#   'N/A'],
#  ['Vivo Y81 Renewed 4GB+64GB 6.22” Dual SIM 3260mAh Smartphone',
#   '56,900',
#   'N/A',
#   '43',
#   '3 out of 5(2)',
#   '100,000'],
#  ['24 Pieces Set Of Luxury Cutlery With Egg Shape Case',
#   '32,500',
#   'N/A',
#   'N/A',
#   '4.5 out of 5(2)',
#   'N/A'],
#  ['Tecno Spark 10 Pro-"6.8\'\'-8/256GB ROM- 50MP-32MP Flash Camera-5000Mah- Android 13 - White',
#   '165,000',
#   'N/A',
#   '17',
#   '4.3 out of 5(10)',
#   '199,800'],
#  ['Nokia 5310 XpressMusic, Bluetooth, MP3, FM, Dual SIM, Color -Black',
#   '30,000',
#   'N/A',
#   'N/A',
#   '4.3 out of 5(36)',
#   'N/A'],
#  ['Electric Vegetable Hammer Food Chopper',
#   '9,500',
#   'N/A',
#   'N/A',
#   '4.2 out of 5(5)',
#   'N/A'],
#  ['Oppo Refurbished A3S 64GB + 4GB RAM - 4G LTE Dual Card - 6.2-inch Display - Face Unlock (blue)',
#   '55,000',
#   'N/A',
#   '29',
#   '4 out of 5(2)',
#   '78,000'],
#  ['SMALL Tecno Button Dual Sim, Cheap Small Techno Basic Phones',
#   '15,999',
#   'N/A',
#   '6',
#   '3.7 out of 5(3)',
#   '17,000'],
#  ['Rechargeable Electric Mosquito Kill Bat Swatter',
#   '7,000',
#   'N/A',
#   'N/A',
#   '5 out of 5(1)',
#   'N/A'],
#  ['IPhone 6S Plus 64GB(Refurbished )-Gold Grade A',
#   '110,098',
#   'N/A',
#   '27',
#   '4.4 out of 5(40)',
#   '149,804'],
#  ['itel 20000mAh Fast Charging, Bright Torch Power Bank+Free Charger',
#   '13,770',
#   'N/A',
#   '72',
#   'N/A',
#   '48,907'],
#  ['Tecno Spark 10 (KI5q) 6.6 128GB 16GB 50MP + 8MP 5000mAh',
#   '128,000',
#   'N/A',
#   '29',
#   '4 out of 5(2)',
#   '180,000'],
#  ['Infinix Smart 7 HD (X6516) 6.6", 64GB ROM + Up To 4GB RAM, 5000mAh',
#   '85,750',
#   'N/A',
#   '14',
#   '4 out of 5(6)',
#   '100,000'],
#  ['Koobee K100 Smartphone 2gb + 16gb Wifi Only (Sim Disabled)',
#   '27,500',
#   'N/A',
#   '26',
#   '3.5 out of 5(2)',
#   '37,000'],
#  ['Tecno POP 5 Go, 5.71" Display, 1GB RAM + 16GB ROM, 4000mAh, Android 10, 5MP +5MP Camera, Fingerprint - Aether Black',
#   '53,999',
#   'N/A',
#   '2',
#   '5 out of 5(1)',
#   '55,000'],
#  ['MAXFONE Big Screen Big Torch Four Sim 2500mAh Phone - V12',
#   '16,900',
#   'N/A',
#   '18',
#   '4.6 out of 5(16)',
#   '20,500'],
#  ['Gionee 5.2 Inch HD Refurbished 16MP+13MP Android Smartphone',
#   '49,400',
#   'N/A',
#   '50',
#   '3.8 out of 5(12)',
#   '98,900'],
#  ['Tecno Camon 20 (CK6) 6.67 256GB + 8GB 64MP Rear + 32MP 5000mAh',
#   '202,500',
#   'N/A',
#   '28',
#   '3.9 out of 5(9)',
#   '280,000'],
#  ['Oppo A3S 99.9%NEW Refurbished 6.2" 4G+64G 13MP 4230mAH FaceUnlock',
#   '53,900',
#   'N/A',
#   '21',
#   '4 out of 5(24)',
#   '68,000'],
#  ['Infinix Smart 7 HD (X6516) 6.6", 64GB ROM + Up To 4GB, 5000mAh, 8MP',
#   '85,990',
#   'N/A',
#   '14',
#   '4.5 out of 5(4)',
#   '100,000'],
#  ['Tecno T301 Dual Sim With Camera & TorchLight Fm, Speaker - Blue',
#   '13,299',
#   'N/A',
#   '26',
#   '4.3 out of 5(123)',
#   '18,000'],
#  ['Refurbished OPPO A31 6.5" 6GB/128GB Dual SIM 12+8MP 4230mAH',
#   '85,740',
#   'N/A',
#   'N/A',
#   '4 out of 5(1)',
#   'N/A'],
#  ['XIAOMI Redmi A2+ 6.52 Inches 3GB RAM 64GB ROM,5000mAH- BLACK',
#   '75,000',
#   'N/A',
#   '23',
#   '4.3 out of 5(9)',
#   '97,000'],
#  ['Infinix Smart 7 HD [6.6"HD+ - (2+2GB RAM, 64GB ROM) - Android 12 OS - 5000mAh - 4G - BLACK]',
#   '72,500',
#   'N/A',
#   '40',
#   '4.7 out of 5(6)',
#   '120,000'],
#  ['itel 20000mAh Dual Output & Input Fast Charging Power Bank',
#   '12,490',
#   'N/A',
#   'N/A',
#   '4.2 out of 5(38)',
#   'N/A'],
#  ['itel A04 6.3" Screen, 2GB RAM + 32GB ROM, 4000mAh, 5MP AI Camera',
#   '57,990',
#   'N/A',
#   '28',
#   '3.8 out of 5(15)',
#   '80,000'],
#  ['P47 Superior 5.0 Wireless Bluetooth Stereo Foldable Headphones',
#   '4,300',
#   'N/A',
#   'N/A',
#   '4 out of 5(13)',
#   'N/A'],
#  ['Tecno POP 7 (BF6) 6.6" HD+, 64GB ROM + Up To 4GB RAM, 5000mAh, 8MP',
#   '84,350',
#   'N/A',
#   '6',
#   '5 out of 5(2)',
#   '90,000'],
#  ['Samsung Galaxy A14 4GB RAM 128GB ROM DUAL SIM- BLACK',
#   '170,000',
#   'N/A',
#   '15',
#   '3.9 out of 5(15)',
#   '199,000'],
#  ['Tecno Spark 10C (KI5k) 6.6", 128GB + 4GB16MP, 5000mAh',
#   '126,000',
#   'N/A',
#   '26',
#   '5 out of 5(2)',
#   '170,000'],
#  ['XIAOMI Redmi Note 12 6.67" 8GB RAM/256GB ROM Android 13 - Gold',
#   '190,800',
#   'Official Store',
#   '36',
#   '4.4 out of 5(5)',
#   '299,500'],
#  ['Samsung Galaxy A04 - 6.5" - 3/32GB - 4G LTE - 50MP - 5000mAh - Black',
#   '91,990',
#   'N/A',
#   '12',
#   'N/A',
#   '104,500'],
#  ['Samsung Note 10 Single Sim 256gb 8gb',
#   '260,000',
#   'N/A',
#   'N/A',
#   '5 out of 5(1)',
#   'N/A'],
#  ['XIAOMI Redmi 12 Sky Blue 8GB RAM 256GB ROM 5000mah',
#   '187,000',
#   'N/A',
#   '32',
#   '3.7 out of 5(3)',
#   '277,000'],
#  ['Oraimo 20000MAH Long Lasting Fast Powerbank - Power For Days',
#   '15,830',
#   'N/A',
#   '37',
#   '1.5 out of 5(2)',
#   '25,000'],
#  ['XIAOMI Redmi A2+ 2GB RAM 32GB ROM 5000mAH - Black',
#   '66,800',
#   'N/A',
#   '11',
#   '4.6 out of 5(7)',
#   '75,000'],
#  ['itel 6360 2.8" Screen, Smart Touch, 2000mAh Dual SIM Feature Phone',
#   '24,990',
#   'N/A',
#   '17',
#   '5 out of 5(1)',
#   '30,000'],
#  ['Idino NoteBook 7 Tablet 10"512G+ 8G,10000mah,+smartwatch,keyboard',
#   '105,000',
#   'N/A',
#   'N/A',
#   '1 out of 5(1)',
#   'N/A'],
#  ['Infinix Hot 30i (X669) 6.6", 128GB, UP TO 8GB RAM, 5000mAh, 13MP, 4G',
#   '141,990',
#   'N/A',
#   '21',
#   '3 out of 5(2)',
#   '180,000'],
#  ['Tecno Pop7 (BF6) 6.6",2GB/64GB(UpTo 4GB RAM), 5000mAh, Blue',
#   '73,999',
#   'N/A',
#   '24',
#   '4.3 out of 5(6)',
#   '98,000'],
#  ['itel A60s (4GB RAM + 128GB ROM) 5000mAh 4G LTE, Black',
#   '88,000',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['itel S23 6.6" 90Hz HD+, 128GB ROM + Up To 8GB RAM, 5000mAh Type-C, 50MP Clear Camera, 4G, Fingerprint & Face ID - Black',
#   '96,590',
#   'N/A',
#   '3',
#   '3 out of 5(4)',
#   '100,000'],
#  ['P47 Wireless Bluetooth Stereo Foldable Headset',
#   '4,450',
#   'N/A',
#   '56',
#   '3.9 out of 5(56)',
#   '10,000'],
#  ['Refurbished Huawei Y8S 2020 6.5-inch Fhd+, 6gb+128gb,4000mAh',
#   '75,560',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ["Samsung Galaxy Note 9 Dual Sim 128gb/6gb 6.4'' Black",
#   '225,000',
#   'N/A',
#   '10',
#   '5 out of 5(2)',
#   '250,000'],
#  ["Samsung Galaxy S9 Single Sim 64gb/4gb 5.8''",
#   '154,000',
#   'N/A',
#   'N/A',
#   '5 out of 5(2)',
#   'N/A'],
#  ['Refurbished Huawei Y8S 2020 6.5-inch Fhd+, 6gb+128gb,4000mAh',
#   '75,766',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['itel Circle 1 Unique Design, Round Screen, Dual SIM Phone - Black',
#   '16,850',
#   'N/A',
#   '16',
#   '3 out of 5(3)',
#   '20,000'],
#  ['itel P40 6.6", 64GB ROM + Up To 7GB RAM, 6000mAh, 13MP + 5MP, 4G',
#   '75,790',
#   'N/A',
#   '11',
#   '5 out of 5(3)',
#   '85,000'],
#  ['Wintouch K81 – 8inches Kids Tablet Sim Enabled, - Purple',
#   '53,000',
#   'N/A',
#   '41',
#   '4.4 out of 5(5)',
#   '90,000'],
#  ['itel Circle 1 Unique Design, Round Screen, Dual SIM Phone - Gold',
#   '17,950',
#   'N/A',
#   '10',
#   'N/A',
#   '20,000'],
#  ['Tecno POP 5 Go, 5.71", 1GB RAM + 16GB ROM, 4000mAh,Mist Copper',
#   '53,900',
#   'N/A',
#   '9',
#   '5 out of 5(2)',
#   '59,000'],
#  ['Nokia 3310 Dual SIM Bluetooth Cellphone-Dark Blue',
#   '30,000',
#   'N/A',
#   'N/A',
#   '4 out of 5(3)',
#   'N/A'],
#  ['Tecno POP 7 (BF6) 6.6" 64GB ROM + 2GB RAM, 5000mAh, 8MP',
#   '67,500',
#   'N/A',
#   '39',
#   '5 out of 5(1)',
#   '110,000'],
#  ['Samsung Galaxy A04, 4GB/64GB Memory - BLACK',
#   '139,000',
#   'N/A',
#   '31',
#   'N/A',
#   '200,000'],
#  ['Samsung Galaxy S21 5G 8+128GB G991U - Purple',
#   '310,000',
#   'N/A',
#   '11',
#   '4 out of 5(2)',
#   '350,000'],
#  ['Bontel L2 Little Lover -Super Slim With Inbuilt Battery Blue',
#   '23,000',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['P47 Wireless Bluetooth Headset',
#   '4,500',
#   'N/A',
#   '55',
#   '4 out of 5(2)',
#   '10,000'],
#  ['itel P40 Plus 6.6", 128GB ROM + Up To 8GB RAM, 7000mAh 18W, 13MP',
#   '106,990',
#   'N/A',
#   '24',
#   '5 out of 5(2)',
#   '140,000'],
#  ['Samsung Galaxy A04s 4GB ROM/128GB ROM Android 12 - Green',
#   '140,100',
#   'Official Store',
#   '26',
#   '4.6 out of 5(22)',
#   '189,500'],
#  ['IPhone 6S Plus 2GB RAM+64GB(Refurbished ) -Silver (Grade A)',
#   '110,098',
#   'N/A',
#   '29',
#   '4.6 out of 5(36)',
#   '155,482'],
#  ['Infinix HOT 30i- (X669)- 128/4GB- \'6.56"-13MP+8MP-5000mAh',
#   '126,000',
#   'N/A',
#   '16',
#   '3.5 out of 5(4)',
#   '150,000'],
#  ['Infinix Hot 30i Free MousePad 128 Rom + 4GB Ram 5000mAh - Android 12 WHITE',
#   '125,900',
#   'N/A',
#   '26',
#   'N/A',
#   '170,000'],
#  ['itel S23 6.6" 128GB ROM + UP TO 8GB RAM, 5000mAh 50MP BLACK',
#   '101,500',
#   'N/A',
#   '20',
#   '4.7 out of 5(3)',
#   '127,000'],
#  ['Infinix HOT 30i- (X669)- 128/4GB UPTO 8GB- \'6.56"-13MP+8MP AI DUAL FLASH Camera-5000mAh-Android™ 12',
#   '126,000',
#   'N/A',
#   '16',
#   '4.6 out of 5(7)',
#   '150,000'],
#  ['Romoss 40000mah Smart Fast Charging Digital Power Bank -2 Inputs',
#   '39,900',
#   'N/A',
#   'N/A',
#   '4.7 out of 5(3)',
#   'N/A'],
#  ["Samsung Galaxy S9 5.8'' Inch QHD ( 4GB + 64GB ROM ) 12MP+8MP _ Midnight Black, Single Sim",
#   '148,000',
#   'N/A',
#   '10',
#   'N/A',
#   '165,000'],
#  ['Refurbished Huawei Psmart 6+128G With Fingerprint 5.65"',
#   '59,759',
#   'N/A',
#   'N/A',
#   '4 out of 5(2)',
#   'N/A'],
#  ['XIAOMI Redmi A2+ 6.52 Inches 3GB RAM 64GB ROM,5000mAH- BLACK',
#   '98,000',
#   'N/A',
#   'N/A',
#   '4 out of 5(1)',
#   'N/A'],
#  ['Tecno Spark 10C - 6.6" (4GB/128GB) 4G Dual SIM, 5000mAh - Black',
#   '117,000',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['itel A70 6.6"HD 4GB RAM 128GB ROM Android 12 - Black',
#   '78,900',
#   'Official Store',
#   '17',
#   'N/A',
#   '95,000'],
#  ['Tecno Spark 10 Pro - 6.8 (8+8GB RAM, 256GB ROM) - Lunar',
#   '169,000',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['XIAOMI REDMI NOTE 12 8GB- RAM- 256GB ROM DUAL -SIM ONYX GRAY',
#   '230,000',
#   'N/A',
#   '8',
#   '4.6 out of 5(5)',
#   '250,000'],
#  ['Samsung Galaxy A04e 6.5" 4GB RAM/128GB ROM - Black',
#   '142,900',
#   'N/A',
#   'N/A',
#   '4 out of 5(1)',
#   'N/A'],
#  ['Apple IPhone 15 Pro 128GB White Titanium - FaceTime - A17 Pro Chip',
#   '1,450,999',
#   'Official Store',
#   '52',
#   'N/A',
#   '2,999,999'],
#  ['itel 20000mAh Dual Input & Dual Output Fast Charging Power Bank',
#   '12,489',
#   'N/A',
#   '27',
#   '4.4 out of 5(28)',
#   '17,000'],
#  ['Bontel USB100 Mobile Mini Bluetooth Headset Phone-BLACK',
#   '16,500',
#   'N/A',
#   'N/A',
#   '3.5 out of 5(2)',
#   'N/A'],
#  ['Gionee Refurbished 5.2 Inch 4GB +32GB Android 4G Smartphone-Gold',
#   '49,400',
#   'N/A',
#   '37',
#   '5 out of 5(2)',
#   '78,900'],
#  ['Samsung Galaxy S21 5G 8+128GB G991U - White',
#   '310,000',
#   'N/A',
#   '11',
#   'N/A',
#   '350,000'],
#  ['itel S23+ 6.78" AMOLED, 256GB ROM + Up To 16GB RAM, 5000mAh, 50MP',
#   '187,750',
#   'N/A',
#   '6',
#   'N/A',
#   '200,000'],
#  ['Infinix Hot 30i Free MousePad 128 Rom + 4GB Ram 5000mAh - Android 12 BLACK',
#   '125,900',
#   'N/A',
#   '26',
#   '1 out of 5(1)',
#   '170,000'],
#  ['Huawei Y6 Pro - 4G LTE - 4GB RAM - 64GB ROM - Fingerprint - Gold',
#   '55,500',
#   'N/A',
#   'N/A',
#   '4 out of 5(1)',
#   'N/A'],
#  ['Infinix Note 10 Pro - 6.95" FHD+ (8GB RAM, 256GB ROM) Android 11 (64/8/2/2)MP + 16MP Selfie - 4G LTE - 5000mAh - Blizzard Snow',
#   '160,000',
#   'N/A',
#   '9',
#   '5 out of 5(2)',
#   '175,000'],
#  ['Nokia 3310 Classic Mobile Phone Dual SIM Long Battery Life Of Grey',
#   '30,000',
#   'N/A',
#   'N/A',
#   '3.9 out of 5(20)',
#   'N/A'],
#  ['SMALL 2160Wireless Fm, Torchlight Phones , Dual SIM - Dark Blue Small Cheapest Button Phone For Cheap Price',
#   '13,900',
#   'N/A',
#   '7',
#   '5 out of 5(2)',
#   '15,000'],
#  ['itel 6350 2.8" Big Screen, Super Slim, 1500mAh JAVA Phone - Blue',
#   '17,950',
#   'N/A',
#   '10',
#   '3.8 out of 5(4)',
#   '20,000'],
#  ['itel S23 Fee Umbrella128GB ROM + 4GB RAM, 5000mAh 50MP',
#   '101,500',
#   'N/A',
#   '15',
#   '3 out of 5(1)',
#   '119,000'],
#  ['Oppo A17K Navy Blue, 6.56", 3GB RAM+64GBROM',
#   '114,900',
#   'Official Store',
#   '9',
#   'N/A',
#   '125,880'],
#  ['Samsung Galaxy Note8 Note 8 Mobile Phone 6.3" 6GB 64GB-Black',
#   '174,000',
#   'N/A',
#   '8',
#   '1 out of 5(1)',
#   '190,000'],
#  ['Genuine Comes With Both Type C And IPhone Plug&Play K8 Wireless Lavalier Microphone For IPhone, IPad, Type C Lapel Clip-on Mini Wireless Mic For TikTok Vlog YouTube, Facebook Live Stream, Auto-syncs Microphone (NO APP Or Bluetooth)',
#   '8,999',
#   'N/A',
#   '10',
#   '4 out of 5(4)',
#   '10,000'],
#  ['XIAOMI Redmi 10A 6.53 Inches 3GB RAM 64GB ROM 5000mAH- Gray',
#   '90,700',
#   'N/A',
#   '6',
#   'N/A',
#   '97,000'],
#  ['Nokia 110 Africa Edition Wireless FM, Torch, Camera, Dual SIM Blue',
#   '13,899',
#   'N/A',
#   '7',
#   '3.7 out of 5(6)',
#   '15,000'],
#  ['itel S23 128GB + 4GB Android 12 WHITE',
#   '86,000',
#   'Official Store',
#   '16',
#   '5 out of 5(1)',
#   '102,048'],
#  ['Bontel L600 1.77 Inch ,Big Speaker, 1000 Mah Battery - Green',
#   '8,800',
#   'N/A',
#   '2',
#   '3.8 out of 5(6)',
#   '9,000'],
#  ['itel It2163,1.77 Screen,Opera Mini, BrightTorch,1000mAh Black',
#   '9,599',
#   'N/A',
#   '17',
#   '4.4 out of 5(21)',
#   '11,500'],
#  ['itel 20000mAh Dual Input & Output Fast Charging Power Bank',
#   '12,499',
#   'N/A',
#   'N/A',
#   '4.6 out of 5(12)',
#   'N/A'],
#  ['Huawei GSM SIM Card Land-Line Table Phone With FM, Black.',
#   '16,960',
#   'N/A',
#   '11',
#   '4.1 out of 5(12)',
#   '19,000'],
#  ['Nokia 2660 Flip - 2.8" 4G LTE - Dual - Black',
#   '76,000',
#   'N/A',
#   '16',
#   '5 out of 5(1)',
#   '90,000'],
#  ['Bontel 2720 1.77 Inch Color Display,Flip Phone- RED',
#   '18,000',
#   'N/A',
#   'N/A',
#   '4.8 out of 5(4)',
#   'N/A'],
#  ['Samsung Galaxy S21 Plus 6.7" 128GB S21+ Smartphone -Black',
#   '360,000',
#   'N/A',
#   '10',
#   'N/A',
#   '400,000'],
#  ['Nokia 5310 XpressMusic Wireless FM Loudspeaker Dual SIM -white And Red',
#   '30,000',
#   'N/A',
#   'N/A',
#   '3.5 out of 5(10)',
#   'N/A'],
#  ['Infinix HOT 30i - 6.56" (4GB/128GB) 4G Dual SIM, 5000mAh - White',
#   '131,000',
#   'N/A',
#   'N/A',
#   '4 out of 5(2)',
#   'N/A'],
#  ['Samsung Galaxy S10 Dual Sim Black 8gb Ram 128gb Rom AMOLED',
#   '250,000',
#   'N/A',
#   '14',
#   '4.9 out of 5(8)',
#   '290,000'],
#  ['Gionee S10c/s10 99.9%NEW Refurbished 5.2" 32G 3100mAh 16Mp DualSIM',
#   '49,000',
#   'N/A',
#   '30',
#   'N/A',
#   '70,000'],
#  ['itel A60s (4GB RAM + 64GB ROM) 5000mAh 4G LTE, Black',
#   '88,000',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['Lenovo Tab P11 2022 --- 6GB + 128GB (Snapdragon 680)',
#   '210,000',
#   'N/A',
#   '24',
#   '5 out of 5(3)',
#   '275,200'],
#  ['Bontel L2 Little Lover -Super Slim Inbuilt Battery-Black',
#   '23,000',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['Samsung Galaxy S10 Plus 6.4-Inch AMOLED 8GB,128GB ROM BLACK',
#   '280,000',
#   'N/A',
#   'N/A',
#   '3.7 out of 5(3)',
#   'N/A'],
#  ['XIAOMI Redmi Note12 6.67" 6GB RAM/128GB ROM Android 13 - Blue',
#   '175,800',
#   'Official Store',
#   '41',
#   '5 out of 5(1)',
#   '299,595'],
#  ['itel P40 Plus 6.6" Screen, 128GB ROM + Up To 8GB RAM, 7000mAh 18W, 13MP Dual Camera, Android 13, 4G, Finger & Face ID - Cyan',
#   '106,990',
#   'N/A',
#   '24',
#   '5 out of 5(3)',
#   '140,000'],
#  ['Bontel L400,1.77 Inch, 0.08MP, Feature Phone,1000mAh, Black',
#   '8,500',
#   'N/A',
#   '15',
#   '4.4 out of 5(14)',
#   '10,000'],
#  ['itel 5081 Triple SIM, Slim Body, Facebook Wireless FM Phone',
#   '12,990',
#   'N/A',
#   '13',
#   '5 out of 5(2)',
#   '15,000'],
#  ['Tecno Spark 10C (KI5k) 6.6" 4GB RAM/128GB ROM Android 12 - Black',
#   '126,000',
#   'N/A',
#   '26',
#   '5 out of 5(3)',
#   '170,000'],
# ...
#  ['Samsung Galaxy S9 5.8-Inch QHD (4GB, 64GB ROM) Android 8.0 Oreo, 12MP + 8MP Single SIM 4G LTE Smartphone - Purple',
#   '165,999',
#   'N/A',
#   '17',
#   '4 out of 5(3)',
#   '200,000'],
#  ['Samsung Galaxy S8 5.8-Inch QHD (4GB,64GB ROM) 12MP + 8MP 4G LTE Smartphone Single Sim - Coral Blue',
#   '170,999',
#   'N/A',
#   '5',
#   '2.5 out of 5(2)',
#   '180,000'],
#  ['Infinix Hot 20i 6.6\'" HD 3GB/64GB Android 12 - Black',
#   '160,000',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['Topcee Heavy Duty Stapler 120F',
#   '13,800',
#   'N/A',
#   'N/A',
#   '3 out of 5(2)',
#   'N/A'],
#  ['itel It2163N,1.77 Screen,Opera Mini,BrightTorch,1000mAh Deep Blue',
#   '9,580',
#   'N/A',
#   '20',
#   'N/A',
#   '12,000'],
#  ['itel 5615 Triple SIM, 2500mAh Big Battery, Wireless FM, Opera Mini - Black',
#   '17,990',
#   'N/A',
#   '10',
#   '4 out of 5(1)',
#   '20,000'],
#  ['Tecno Phantom X2 - Full Screen Protector Tempered Glass',
#   '5,499',
#   'N/A',
#   '48',
#   'N/A',
#   '10,500'],
#  ['Computer Monitor USB Lamp Screen Light Bar LED + RGB',
#   '26,500',
#   'N/A',
#   '40',
#   'N/A',
#   '44,000'],
#  ['Samsung Galaxy Note 8 6.3" Dual Sim 64gb/6gb',
#   '175,000',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['Recrsi Wireless Bluetooth HD Voice Neckband Earphone Headset',
#   '6,000',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['Samsung Galaxy Tab S6 Lite - 64GB-4GB RAM-4G LTE(2022 Model) -Gray',
#   '380,000',
#   'N/A',
#   '16',
#   'N/A',
#   '450,000'],
#  ['Tecno POP 7 6.6" 2GB RAM/ 64GB ROM Android 12 - Blue',
#   '78,998',
#   'N/A',
#   '19',
#   'N/A',
#   '97,600'],
#  ['Firman POWER BANK 15000MAH SUPER STRONG BRAND WITH TORCH',
#   '10,900',
#   'N/A',
#   '73',
#   'N/A',
#   '39,994'],
#  ['Samsung Galaxy A14 6.6" 4GB RAM/64GB ROM Android 13 - GREEN',
#   '198,000',
#   'N/A',
#   'N/A',
#   '5 out of 5(1)',
#   'N/A'],
#  ['Samsung Galaxy S20 5G 6.2" 128GB ROM, 8GB RAM, Single Sim - Red',
#   '295,000',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['Samsung Galaxy S10 6.1" Single Sim 128gb/8gb',
#   '225,000',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['itel P40 PLUS-6.8"HD+-128/4GBRAM-13/8MP-4G LTE-7000MAH/18W-CYAN',
#   '107,000',
#   'N/A',
#   '11',
#   'N/A',
#   '120,000'],
#  ['TECLAST T40 Pro 8GB Ram + 128GB Rom - Android Tablet',
#   '197,550',
#   'N/A',
#   '7',
#   '5 out of 5(1)',
#   '213,000'],
#  ['Tecno Pop 7 Pro 3GBRAM + 64GB ROM - Orange',
#   '105,300',
#   'N/A',
#   '19',
#   'N/A',
#   '130,000'],
#  ['itel 5606 2500mAh Big Battery Dual SIM Phone -Blue',
#   '12,990',
#   'N/A',
#   '13',
#   '4.3 out of 5(43)',
#   '15,000'],
#  ['Samsung Tab S8 Plus 12.4" - 8GB RAM - 256GB - 5G - Graphite',
#   '998,900',
#   'N/A',
#   '90',
#   'N/A',
#   '9,900,000'],
#  ['Tecno T402, 2.4 Inches, Java, Tripple Sim, Opera, 1500mAh',
#   '19,300',
#   'N/A',
#   '16',
#   'N/A',
#   '23,000'],
#  ['LAND LINE TABLE PHONE FOR OFFICE AND HOME',
#   '14,500',
#   'N/A',
#   '3',
#   '4.4 out of 5(5)',
#   '15,000'],
#  ["Samsung Galaxy Note 10 (8gb+ 256GB) 6.3'',12MP 2x Zoom, 16MP Ultra Wide Rear+10MP Selfie Camera With Dual Pixel,3500mAh - Aura Glow",
#   '270,000',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['Phone Tripod Stand Kit & Remote Control Lightweight Portable',
#   '7,820',
#   'N/A',
#   '48',
#   'N/A',
#   '15,100'],
#  ["Samsung Galaxy S21 5G - 6.2'' 8GB RAM 128GB ROM Auto-HDR - 4000mAh",
#   '310,000',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['Huawei P50 Pro - Full Screen Protector Tempered Glass',
#   '3,999',
#   'N/A',
#   '62',
#   'N/A',
#   '10,500'],
#  ['itel It5606, 1.77 Screen,Feature Phone,2500mAh Big Battery,Dual SIM Phone -City Blues',
#   '13,000',
#   'N/A',
#   '10',
#   '4.3 out of 5(39)',
#   '14,500'],
#  ['Bontel Music King-2.8inch Display Screen,15000mAh 4sim Black',
#   '23,000',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['itel A60s (64GB ROM + Up To 8GB RAM) 5000mah Green',
#   '90,000',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['Infinix Smart 7 HD 6.6" 2GB RAM/64GB ROM 4G Android 12-Green',
#   '79,000',
#   'N/A',
#   '17',
#   'N/A',
#   '95,000'],
#  ['Samsung Galaxy A04E Free Mousepad 3GB RAM/64GB ROM 13MP Android 12',
#   '105,000',
#   'N/A',
#   '23',
#   'N/A',
#   '136,000'],
#  ['Samsung Galaxy Tab S8 Ultra Book Cover Keyboard - Black',
#   '399,000',
#   'N/A',
#   '11',
#   '5 out of 5(1)',
#   '450,000'],
#  ["XIAOMI Poco M4 Pro 5G, 6.6'' 4GB RAM 64GB ROM Android 11 - Black",
#   '290,000',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['itel P38 Pro 6.8"HD+-64/2GB RAM-13MP-FACE UNLOCK-6000mAh-BLUE',
#   '71,000',
#   'N/A',
#   '5',
#   'N/A',
#   '75,000'],
#  ['7 Colour Bluetooth Keyboard & Touchpad For Phones.',
#   '22,500',
#   'N/A',
#   '61',
#   'N/A',
#   '57,500'],
#  ['BM800 Condenser Microphone + V8S Soundcard Live Music Tiktok',
#   '39,800',
#   'N/A',
#   '12',
#   '5 out of 5(1)',
#   '45,000'],
#  ['Samsung Galaxy S8+ S8 Plus LTE Android Cell Phone 6.2" 12MP (4GB, 64GB ROM)- Blue',
#   '165,000',
#   'N/A',
#   '3',
#   '3 out of 5(1)',
#   '170,000'],
#  ['itel It2163,1.77 Screen,Opera Mini, BrightTorch,1000mAh Deep Blue',
#   '9,499',
#   'N/A',
#   '19',
#   '4.1 out of 5(81)',
#   '11,700'],
#  ['BM800 Condenser Microphone + V9 Soundcard - Music Production',
#   '49,400',
#   'N/A',
#   '18',
#   '4.5 out of 5(2)',
#   '60,000'],
#  ['Tecno T528 - 2.8 Inch, Dual Sim, FM Radio, Camera - Black',
#   '23,600',
#   'N/A',
#   '6',
#   'N/A',
#   '25,000'],
#  ['Tecno POP 8 (BG6) 6.6" HD+, 64GB ROM/3GB RAM 5000mAh, 8MP',
#   '80,300',
#   'N/A',
#   '46',
#   'N/A',
#   '150,000'],
#  ['Bontel L600 1.77 Inch ,Big Speaker, 1000 Mah Battery - Black',
#   '8,800',
#   'N/A',
#   '12',
#   '5 out of 5(2)',
#   '10,000'],
#  ['Bontel S3 1.77 Inch Colour Display,Flip - Red',
#   '19,000',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['Samsung Galaxy A14 - 6.6" (4GB RAM, 128GB ROM) 50MP+13MP 5000mAh',
#   '185,000',
#   'N/A',
#   '8',
#   'N/A',
#   '200,000'],
#  ['Infinix Smart 7Plus - 6.6" HD+ (3+3GB RAM, 64GB ROM) Android 12 (13MP +Ai) + 5MP Selfie - 4G LTE - 6000mAh - Green',
#   '99,999',
#   'N/A',
#   '41',
#   '2 out of 5(1)',
#   '170,000'],
#  ['Infinix Hot 30 (X6831) 6.78", 128GB + Upto 16GB RAM, 50MP, Android13',
#   '171,990',
#   'N/A',
#   '14',
#   'N/A',
#   '200,000'],
#  ['Apple IPhone 15 Pro 128GB - 5G - Black Titanium',
#   '1,650,000',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['Bontel L400, 1.77" ,Dual SIM, FM Radio, Black',
#   '8,499',
#   'N/A',
#   '15',
#   'N/A',
#   '9,950'],
#  ['itel It 5606 2500mAh Big Battery, FM, Facebook,Black',
#   '13,250',
#   'N/A',
#   '12',
#   'N/A',
#   '15,000'],
#  ['Samsung Galaxy Note 10 AMOLED, HDR10+ Corning Gorilla Glass6',
#   '245,000',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['S-TEK USB 2.0 Printer Cable 1.5 Metre - Black',
#   '3,000',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ["Honor 70 5G 6.67'' 8GB 256GB ROM Android 12 - Midnight Black",
#   '460,000',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['Samsung Galaxy S22+ S22 Plus S9060 5G 8+128GB BLACK',
#   '500,000',
#   'N/A',
#   '6',
#   'N/A',
#   '530,000'],
#  ['Siccoo M1- BT Dialer, Torch, Dual SIM, 1.6 Inches, Mini Phone.',
#   '18,500',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['Samsung Galaxy S9 Single Sim (64gb Ram 4gb Rom) + Free Pouch',
#   '185,000',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['Samsung Galaxy S23 Ultra Full Screen Protector Tempered Glas',
#   '5,999',
#   'N/A',
#   '43',
#   'N/A',
#   '10,500'],
#  ['Infinix Hot 30i 6.6\'" HD+, 4+4GB RAM /128GB ROM Android 12 - Blue',
#   '132,355',
#   'N/A',
#   '5',
#   '4.6 out of 5(8)',
#   '139,000'],
#  ['XIAOMI Redmi 12 6.79" 4GB RAM 128GB ROM Android 13 - Midnight Black',
#   '175,000',
#   'N/A',
#   '13',
#   'N/A',
#   '200,000'],
#  ['V8S Soundcard For Music Production Tiktok Live Instagram Etc',
#   '21,500',
#   'N/A',
#   '28',
#   'N/A',
#   '30,000'],
#  ['Samsung Galaxy S20 Ultra 5G - Armor Case With Magnetic Stand',
#   '9,499',
#   'N/A',
#   '27',
#   'N/A',
#   '12,999'],
#  ['XIAOMI Redmi 12C, 6.53-inch ,3GB RAM, 64GB ROM Mint Green',
#   '87,000',
#   'N/A',
#   '28',
#   'N/A',
#   '121,000'],
#  ['Samsung Galaxy A14, 4GB/128GB Memory 4G Black',
#   '188,900',
#   'N/A',
#   '37',
#   'N/A',
#   '300,000'],
#  ["Samsung Galaxy S21 5G 6.2'' (128GB ROM 8GB RAM) Single Sim - Gray",
#   '298,000',
#   'N/A',
#   'N/A',
#   '4.5 out of 5(17)',
#   'N/A'],
#  ['Bontel L1-Super Slim Metal Body. Hidden Top HD Black',
#   '21,000',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['New Model 14 Inches Ringlight', '26,000', 'N/A', '68', 'N/A', '80,000'],
#  ['Tecno Spark 9T - 6.6" (4+3GB RAM, 64GB ROM) Android 12 - 13MP Ai Triple + 32MP Selfie - 4G - Dual - 5000mAh - Quantum Black',
#   '124,999',
#   'N/A',
#   '58',
#   'N/A',
#   '300,000'],
#  ['Samsung A33 - 6.4" (6GB RAM, 128GB ROM) Android 12 - 5G - Dual Sim - 5000mAh - Awesome WHITE',
#   '354,500',
#   'N/A',
#   '29',
#   'N/A',
#   '500,000'],
#  ['Samsung Galaxy Note 10 Plus Single Sim 256/12gb',
#   '360,000',
#   'N/A',
#   'N/A',
#   '5 out of 5(1)',
#   'N/A'],
#  ['Nokia 210, Dual SIM, Opera Mini, Camera, Torch, FM Phone , Black',
#   '26,000',
#   'N/A',
#   'N/A',
#   '3 out of 5(4)',
#   'N/A'],
#  ['Idino Notepad 8 5G With Keyboard, 8", 256GB/6GB, 4000mAh',
#   '80,000',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['Tecno Pop 7 Pro (BF7) 6.6", 4GB RAM(Up To 7GB) + 64GB ROM, 5000mAh Type-C, 13MP Rear + 5MP Selfie - Blue',
#   '102,000',
#   'N/A',
#   '18',
#   'N/A',
#   '125,000'],
#  ['Oraimo FreePods4 Active Noise Cancellation Easy Control APP35.5-hr',
#   '26,990',
#   'N/A',
#   '3',
#   'N/A',
#   '27,698'],
#  ['Samsung Galaxy S21 Ultra 5G (12GB/128GB) Single Sim-Phantom Black',
#   '485,000',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ["Blackview Oscal C20 6.088'' 1GB RAM/32GB RAM Android 11 - Midnight Black",
#   '65,990',
#   'Official Store',
#   '17',
#   'N/A',
#   '79,188'],
#  ['Samsung Galaxy Z Flip5 5G - (8GB RAM, 512GB ROM) -Graphite',
#   '1,700,000',
#   'N/A',
#   '15',
#   'N/A',
#   '2,000,000'],
#  ['MAXFONE Max6, Ultra Thin Design, SIM Card Blue',
#   '19,500',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['Tecno T101 DualSim, Stylish Design, Torchlight, Fm- Black',
#   '11,500',
#   'N/A',
#   '18',
#   'N/A',
#   '14,000'],
#  ['Oppo A18 (4GB RAM + 128GB) 4G, 5000mAh-Glowing Black',
#   '145,000',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['Tecno T352, Dual Sim With Camera Gold',
#   '19,400',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['Ldnio 3 In 1, 3.4A Type C, Micro USB, IOS Fast Charger Cable',
#   '4,460',
#   'N/A',
#   '31',
#   'N/A',
#   '6,500'],
#  ['Satin Skinz Juliet Eve (satinskinz) Women Beauty Supplement',
#   '25,999',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['Samsung Galaxy A33 5G -Smart View Protective Flip Case Pouch',
#   '5,499',
#   'N/A',
#   '48',
#   'N/A',
#   '10,500'],
#  ['itel S18 6.6", 64GB ROM + 2GB RAM (UpTo 4GB), 5000mAh, 4G - Green',
#   '79,999',
#   'N/A',
#   '20',
#   'N/A',
#   '100,000'],
#  ['Samsung Galaxy S22 5G - 6.1", 128GB ROM,8GB RAM, Single Sim - Black',
#   '530,000',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['Apple Iphone XR 64gb 3gb 6.1inch Yellow Free Case & Screen Guide',
#   '301,000',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['Nokia 216 - Dual Sim -2.4" -Camera - Torch-Fm Radio-1020mAh-Black',
#   '26,000',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['Nokia 6310 Classic Design, Wireless FM Feature Phone - Black',
#   '32,000',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['Samsung Galaxy Z Fold 4 - 7.6" (12GB RAM, 256GB ROM) Android 12 (50/10/12)MP + 4/10MP Selfie - Snapdragon 5G - 4400mAh - Graygreen',
#   '1,765,000',
#   'N/A',
#   '12',
#   'N/A',
#   '2,000,000'],
#  ['Samsung Galaxy Note 10 Plus 256gb 12gb Single Sim',
#   '360,000',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['Samsung Galaxy S20 Ultra 5G 6.9" 128GB ROM 12GB RAM,Single Sim-Black',
#   '330,000',
#   'N/A',
#   'N/A',
#   '4.2 out of 5(20)',
#   'N/A'],
#  ['Tecno T528 - 2.8 Inch, Radio, Opera Mini, Battery 2500mAH- Gold',
#   '23,400',
#   'N/A',
#   '6',
#   'N/A',
#   '25,000'],
#  ['itel 2173 Wireless FM, Opera Mini, Torch, Dual SIM- Color: Black',
#   '10,790',
#   'N/A',
#   '1',
#   '4 out of 5(6)',
#   '10,800'],
#  ['itel A60 6.6" HD+ Screen 2GB RAM/32GB ROM Android 12 - Black',
#   '68,000',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ["Oneplus Nord CE 3 Lite 5G 6.72'' 8GB RAM 256GB ROM Android 13 - Gray",
#   '340,000',
#   'N/A',
#   '3',
#   'N/A',
#   '350,000'],
#  ['Samsung Galaxy Tab S8 Plus 12.4" - 8GB RAM - 128GB - 5G - Graphite',
#   '1,049,500',
#   'N/A',
#   '65',
#   'N/A',
#   '3,000,000'],
#  ['Oppo Reno8T 4G Midnight Black, 6.43", 8+256GB, 100MP CAMERA',
#   '337,000',
#   'Official Store',
#   '16',
#   '4 out of 5(1)',
#   '399,595'],
#  ['Samsung Galaxy S9 5.8-Inch QHD (4GB, 64GB ROM) - Lilac Purple',
#   '145,000',
#   'N/A',
#   'N/A',
#   '4.6 out of 5(13)',
#   'N/A'],
#  ['itel A60 6.6" HD+ 2GB RAM 32GB ROM Android 12 - Blue',
#   '68,000',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['Bontel L1200, 1.77"inch Screen, GSM,0.08MP, MP3, MP4,1000mAh, Green',
#   '8,500',
#   'N/A',
#   '3',
#   'N/A',
#   '8,799'],
#  ['Echo Dot (5th Gen-2022) Smart Speaker - Charcoal',
#   '57,800',
#   'N/A',
#   '11',
#   '4.5 out of 5(2)',
#   '64,600'],
#  ['Nokia M10 Mobile Mini Bluetooth Headset Phone-orenge',
#   '15,000',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['Tecno T485, 2.8" Inch, Dual SIM, 4000mah Battery, - Black',
#   '25,999',
#   'N/A',
#   '10',
#   '5 out of 5(1)',
#   '29,000'],
#  ['Bontel TV Touch- 3.5 Inch Touch Screen TV Phone - Black',
#   '23,000',
#   'N/A',
#   'N/A',
#   '5 out of 5(2)',
#   'N/A'],
#  ['Tecno Camon 20 Pro (8GB RAM + 256GB ROM) Blue',
#   '250,000',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['Kinelco Double Burner Ring Plate', '19,999', 'N/A', 'N/A', 'N/A', 'N/A'],
#  ['Samsung Galaxy A12 5G - Rugged Shield Case (Armored Pouch)',
#   '10,500',
#   'N/A',
#   '16',
#   'N/A',
#   '12,500'],
#  ["Infinix Smart 6- (X657) - 4G LTE - 32GB ROM - 2GB RAM - 6.6'' HD+ Waterdrop - 5000mAh - Black + Free Gift",
#   '89,999',
#   'N/A',
#   '31',
#   'N/A',
#   '130,000'],
#  ['XIAOMI 12 Pro - 6.73" (12GB RAM, 256GB ROM) Android 12 (50/50/50)MP + 32MP Selfie - Snapdragon 5G - Dual - 4600mAh - Grey',
#   '795,000',
#   'N/A',
#   '12',
#   '3 out of 5(1)',
#   '900,000'],
#  ['Samsung Galaxy S20 6.2inch 12GB / 128GB Octa-core Hybrid Zoom 5G',
#   '245,000',
#   'N/A',
#   'N/A',
#   '4.5 out of 5(13)',
#   'N/A'],
#  ['Bontel L800 1.77 Inch Big Screen,Big Speaker,Power Bank Option, 1000 Mah Battery,60 Day Standby Time - Green',
#   '12,000',
#   'N/A',
#   'N/A',
#   '3.9 out of 5(42)',
#   'N/A'],
#  ['Oppo R15X Refurbished 6.4"6+128GB16MP+25MP Camera 4G 3600mAh',
#   '75,990',
#   'N/A',
#   '24',
#   'N/A',
#   '100,000'],
#  ['Tecno Camon 20 (CK6) 6.67" 8GB RAM/256GB ROM Android 13.',
#   '220,000',
#   'N/A',
#   '24',
#   'N/A',
#   '290,000'],
#  ['XIAOMI Poco M5, 6.58" (6GB RAM, 128GB ROM) Android 12 (50/2/2)MP + 5MP Selfie - 4G - Dual Sim - 5000mAh - Black',
#   '188,000',
#   'N/A',
#   '15',
#   'N/A',
#   '220,000'],
#  ['Xiaoxin Pad 2022 - 6GB+128GB Android 12',
#   '230,200',
#   'N/A',
#   '23',
#   'N/A',
#   '298,200'],
#  ['itel A60s (128GB ROM + Up To 8GB RAM) 5000mAh 4G Black',
#   '98,000',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['Mez H2Ah Big Battery, Wireless FM, Facebook, Dual SIM Phone',
#   '12,000',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['Lenovo Tab P11 (2nd Gen) 6GB +128GB',
#   '278,200',
#   'N/A',
#   '26',
#   'N/A',
#   '375,000'],
#  ['Samsung Galaxy A04e - 6.5" - 64GB ROM - 3GB RAM - Dual SIM - 4G LTE - 13MP - 5000mAh - Light Blue',
#   '109,999',
#   'N/A',
#   '21',
#   'N/A',
#   '140,000'],
#  ['Oppo Reno8T 4G Sunset Orange, 6.43", 8+256GB, 100MP CAMERA',
#   '337,000',
#   'Official Store',
#   '16',
#   'N/A',
#   '399,595'],
#  ['Samsung S23 Dual SIM - 8GB RAM - 256GB - 5G - Green',
#   '912,500',
#   'N/A',
#   '52',
#   '5 out of 5(1)',
#   '1,900,000'],
#  ['Fifine Ampligame RGB USB Microphone A6V For Podcast Youtube',
#   '46,350',
#   'N/A',
#   '28',
#   'N/A',
#   '64,000'],
#  ['Samsung Galaxy Note 9 6GB/128GB Single SIM Li-Ion 4000 MAh 6.4 Inch',
#   '200,000',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['Oppo Reno8T 5G Midnight Black, 6.7", 8+256GB, 108MP CAMERA',
#   '447,000',
#   'Official Store',
#   '25',
#   'N/A',
#   '599,595'],
#  ['Samsung Galaxy A14 - 6.6" (4GB RAM, 64GB ROM) - Light Green',
#   '179,500',
#   'N/A',
#   '40',
#   'N/A',
#   '300,000'],
#  ['Samsung Galaxy A54 5G 6.4" 128GB/6GB - White',
#   '420,800',
#   'N/A',
#   '19',
#   'N/A',
#   '520,000'],
#  ['Samsung S10 Single Sim 128gb 8gb',
#   '225,000',
#   'N/A',
#   'N/A',
#   '5 out of 5(1)',
#   'N/A'],
#  ['Fifine T669 Condenser Microphone Boom USB Studio Recording',
#   '58,500',
#   'N/A',
#   '31',
#   'N/A',
#   '84,500'],
#  ['Apple IPHONE 11 PRO MAX 64/4GB (12PM+12PM+12PM) 6.5" 3969mAh',
#   '610,000',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['Vivo Y17s- 6.56",6GB/128GB,50/2MP+8MP,4G,5000mAh-Forest Green',
#   '140,500',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['Samsung Galaxy A34 5G 6.6" 8GB 128GB ROM Android 13 Awesome Lime',
#   '299,900',
#   'N/A',
#   '25',
#   'N/A',
#   '400,000'],
#  ...]
