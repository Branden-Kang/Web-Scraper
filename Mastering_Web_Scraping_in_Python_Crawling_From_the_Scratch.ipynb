# %% [markdown]
# [Reference](https://betterprogramming.pub/mastering-web-scraping-in-python-crawling-from-scratch-cb510bcb9fb6)

# %%
import requests 
from bs4 import BeautifulSoup 
import queue 
from threading import Thread 
 
starting_url = 'https://scrapeme.live/shop/page/1/' 
visited = set() 
max_visits = 100 # careful, it will crawl all the pages 
num_workers = 5 
data = [] 
 
def get_html(url): 
	try: 
		response = requests.get(url) 
		# response = requests.get(url, headers=headers, proxies=proxies) 
		return response.content 
	except Exception as e: 
		print(e) 
		return '' 
 
def extract_links(soup): 
	return [a.get('href') for a in soup.select('a.page-numbers') 
			if a.get('href') not in visited] 
 
def extract_content(soup): 
	for product in soup.select('.product'): 
		data.append({ 
			'id': product.find('a', attrs={'data-product_id': True})['data-product_id'], 
			'name': product.find('h2').text, 
			'price': product.find(class_='amount').text 
		}) 
 
def crawl(url): 
	visited.add(url) 
	print('Crawl: ', url) 
	html = get_html(url) 
	soup = BeautifulSoup(html, 'html.parser') 
	extract_content(soup) 
	links = extract_links(soup) 
	for link in links: 
		if link not in visited: 
			q.put(link) 
 
def queue_worker(i, q): 
	while True: 
		url = q.get() # Get an item from the queue, blocks until one is available 
		if (len(visited) < max_visits and url not in visited): 
			crawl(url) 
		q.task_done() # Notifies the queue that the item has been processed 
 
q = queue.Queue() 
for i in range(num_workers): 
	Thread(target=queue_worker, args=(i, q), daemon=True).start() 
 
q.put(starting_url) 
q.join() # Blocks until all items in the queue are processed and marked as done 
 
print('Done') 
print('Visited:', visited) 
print('Data:', data)
# Out:
# Crawl:  https://scrapeme.live/shop/page/1/
# Crawl: Crawl:  https://scrapeme.live/shop/page/3/
#  Crawl:  https://scrapeme.live/shop/page/4/
# Crawl:  https://scrapeme.live/shop/page/46/
# https://scrapeme.live/shop/page/2/
# Crawl:  https://scrapeme.live/shop/page/47/
# Crawl: Crawl:  https://scrapeme.live/shop/page/48/
#  https://scrapeme.live/shop/page/5/
# Crawl:  https://scrapeme.live/shop/page/6/
# Crawl:  https://scrapeme.live/shop/page/7/
# Crawl:  https://scrapeme.live/shop/page/45/
# Crawl:  https://scrapeme.live/shop/page/43/
# Crawl:  https://scrapeme.live/shop/page/44/
# Crawl:  https://scrapeme.live/shop/page/8/
# Crawl:  https://scrapeme.live/shop/page/9/
# Crawl:  https://scrapeme.live/shop/page/10/
# Crawl:  https://scrapeme.live/shop/page/42/
# Crawl:  https://scrapeme.live/shop/page/40/
# Crawl:  https://scrapeme.live/shop/page/41/
# Crawl: Crawl:  https://scrapeme.live/shop/page/12/
#  https://scrapeme.live/shop/page/11/
# Crawl:  https://scrapeme.live/shop/page/13/
# Crawl:  https://scrapeme.live/shop/page/39/
# Crawl:  https://scrapeme.live/shop/page/37/
# Crawl:  https://scrapeme.live/shop/page/38/
# Crawl:  https://scrapeme.live/shop/page/14/
# Crawl:  https://scrapeme.live/shop/page/15/
# Crawl:  https://scrapeme.live/shop/page/16/
# Crawl:  https://scrapeme.live/shop/page/36/
# Crawl:  https://scrapeme.live/shop/page/34/
# Crawl:  https://scrapeme.live/shop/page/35/
# Crawl:  https://scrapeme.live/shop/page/17/
# Crawl:  https://scrapeme.live/shop/page/18/
# Crawl:  https://scrapeme.live/shop/page/19/
# Crawl:  https://scrapeme.live/shop/page/33/
# Crawl:  https://scrapeme.live/shop/page/31/
# Crawl:  https://scrapeme.live/shop/page/32/
# Crawl:  https://scrapeme.live/shop/page/20/
# Crawl:  https://scrapeme.live/shop/page/21/
# Crawl: Crawl:  https://scrapeme.live/shop/page/22/
#  https://scrapeme.live/shop/page/30/
# Crawl:  https://scrapeme.live/shop/page/28/
# Crawl:  https://scrapeme.live/shop/page/29/
# Crawl:  https://scrapeme.live/shop/page/23/
# Crawl:  https://scrapeme.live/shop/page/24/
# Crawl:  https://scrapeme.live/shop/page/25/
# Crawl:  https://scrapeme.live/shop/page/27/
# Crawl:  https://scrapeme.live/shop/page/26/
# Done
# Visited: {'https://scrapeme.live/shop/page/2/', 'https://scrapeme.live/shop/page/47/', 'https://scrapeme.live/shop/page/30/', 'https://scrapeme.live/shop/page/6/', 'https://scrapeme.live/shop/page/42/', 'https://scrapeme.live/shop/page/43/', 'https://scrapeme.live/shop/page/1/', 'https://scrapeme.live/shop/page/5/', 'https://scrapeme.live/shop/page/10/', 'https://scrapeme.live/shop/page/41/', 'https://scrapeme.live/shop/page/32/', 'https://scrapeme.live/shop/page/25/', 'https://scrapeme.live/shop/page/8/', 'https://scrapeme.live/shop/page/37/', 'https://scrapeme.live/shop/page/35/', 'https://scrapeme.live/shop/page/44/', 'https://scrapeme.live/shop/page/13/', 'https://scrapeme.live/shop/page/24/', 'https://scrapeme.live/shop/page/36/', 'https://scrapeme.live/shop/page/27/', 'https://scrapeme.live/shop/page/20/', 'https://scrapeme.live/shop/page/21/', 'https://scrapeme.live/shop/page/19/', 'https://scrapeme.live/shop/page/7/', 'https://scrapeme.live/shop/page/48/', 'https://scrapeme.live/shop/page/39/', 'https://scrapeme.live/shop/page/26/', 'https://scrapeme.live/shop/page/11/', 'https://scrapeme.live/shop/page/34/', 'https://scrapeme.live/shop/page/40/', 'https://scrapeme.live/shop/page/14/', 'https://scrapeme.live/shop/page/29/', 'https://scrapeme.live/shop/page/3/', 'https://scrapeme.live/shop/page/18/', 'https://scrapeme.live/shop/page/4/', 'https://scrapeme.live/shop/page/15/', 'https://scrapeme.live/shop/page/46/', 'https://scrapeme.live/shop/page/23/', 'https://scrapeme.live/shop/page/28/', 'https://scrapeme.live/shop/page/33/', 'https://scrapeme.live/shop/page/17/', 'https://scrapeme.live/shop/page/22/', 'https://scrapeme.live/shop/page/12/', 'https://scrapeme.live/shop/page/45/', 'https://scrapeme.live/shop/page/31/', 'https://scrapeme.live/shop/page/38/', 'https://scrapeme.live/shop/page/16/', 'https://scrapeme.live/shop/page/9/'}
# Data: [{'id': '759', 'name': 'Bulbasaur', 'price': '£63.00'}, {'id': '729', 'name': 'Ivysaur', 'price': '£87.00'}, {'id': '730', 'name': 'Venusaur', 'price': '£105.00'}, {'id': '731', 'name': 'Charmander', 'price': '£48.00'}, {'id': '732', 'name': 'Charmeleon', 'price': '£165.00'}, {'id': '733', 'name': 'Charizard', 'price': '£156.00'}, {'id': '734', 'name': 'Squirtle', 'price': '£130.00'}, {'id': '735', 'name': 'Wartortle', 'price': '£123.00'}, {'id': '736', 'name': 'Blastoise', 'price': '£76.00'}, {'id': '737', 'name': 'Caterpie', 'price': '£73.00'}, {'id': '738', 'name': 'Metapod', 'price': '£148.00'}, {'id': '739', 'name': 'Butterfree', 'price': '£162.00'}, {'id': '740', 'name': 'Weedle', 'price': '£25.00'}, {'id': '741', 'name': 'Kakuna', 'price': '£148.00'}, {'id': '742', 'name': 'Beedrill', 'price': '£168.00'}, {'id': '743', 'name': 'Pidgey', 'price': '£159.00'}, {'id': '774', 'name': 'Clefairy', 'price': '£160.00'}, {'id': '775', 'name